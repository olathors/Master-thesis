# %%
import pandas as pd

pd.set_option('display.max_rows', 500)

# %%
df_patients = pd.read_csv('/Users/olath/Documents/GitHub/Master-thesis/Data_Experimentation/data/All_Subjects_DXSUM_24Oct2024.csv')
df_images = pd.read_csv('/Users/olath/Documents/GitHub/Master-thesis/Data_Experimentation/data/Big_cohort_MRI_Images_25Oct2024.csv')

# %%
df_patients.head()
# Out:
#    PHASE        PTID  RID VISCODE VISCODE2    EXAMDATE  DIAGNOSIS  DXNORM  \
# 0  ADNI1  011_S_0002    2      bl       bl  2005-09-29        1.0     1.0
# 1  ADNI1  011_S_0003    3      bl       bl  2005-09-30        3.0    -4.0
# 2  ADNI1  011_S_0005    5      bl       bl  2005-09-30        1.0     1.0
# 3  ADNI1  011_S_0008    8      bl       bl  2005-09-30        1.0     1.0
# 4  ADNI1  022_S_0007    7      bl       bl  2005-10-06        3.0    -4.0
#
#    DXNODEP  DXMCI  ... DXODES  DXCONFID  ID  SITEID    USERDATE  USERDATE2  \
# 0     -4.0   -4.0  ...   -4.0       4.0   2     107  2005-10-01        NaN
# 1     -4.0   -4.0  ...   -4.0       3.0   4     107  2005-10-01        NaN
# 2     -4.0   -4.0  ...   -4.0       4.0   6     107  2005-10-01        NaN
# 3     -4.0   -4.0  ...   -4.0       3.0   8     107  2005-10-01        NaN
# 4     -4.0   -4.0  ...   -4.0       4.0  10      10  2005-10-06        NaN
#
# ...

# %%
patient = '127_S_1427'

df_patients.query('PTID == @patient')
# Out:
#         PHASE        PTID   RID VISCODE VISCODE2    EXAMDATE  DIAGNOSIS  \
# 1826    ADNI1  127_S_1427  1427      bl       bl  2007-09-03        2.0
# 2385    ADNI1  127_S_1427  1427     m06      m06  2008-02-27        2.0
# 2883    ADNI1  127_S_1427  1427     m12      m12  2008-09-11        3.0
# 3260    ADNI1  127_S_1427  1427     m18      m18  2009-03-31        3.0
# 3532    ADNI1  127_S_1427  1427     m24      m24  2009-11-17        3.0
# 4004   ADNIGO  127_S_1427  1427     m36      m36  2010-12-20        3.0
# 4928    ADNI2  127_S_1427  1427     v06      m48  2011-08-24        3.0
# 6513    ADNI2  127_S_1427  1427     v11      m60  2012-09-27        3.0
# 7921    ADNI2  127_S_1427  1427     v21      m72  2013-08-30        3.0
# 8865    ADNI2  127_S_1427  1427     v31      m84  2014-08-29        3.0
# 9371    ADNI2  127_S_1427  1427     v41      m96  2015-08-25        3.0
# 9887    ADNI2  127_S_1427  1427     v51     m108  2016-09-13        3.0
# ...

# %%
df_images.query('subject_id == @patient')
# Out:
#      image_id  subject_id mri_visit    mri_date  \
# 38      69349  127_S_1427        sc  2007-08-20
# 39      69350  127_S_1427        sc  2007-08-20
# 40      69351  127_S_1427        sc  2007-08-20
# 41      69352  127_S_1427        sc  2007-08-20
# 42      69353  127_S_1427        sc  2007-08-20
# 43      69354  127_S_1427        sc  2007-08-20
# 44      69355  127_S_1427        sc  2007-08-20
# 45      69356  127_S_1427        sc  2007-08-20
# 46      69357  127_S_1427        sc  2007-08-20
# 47      91501  127_S_1427       m06  2008-02-19
# 48      91502  127_S_1427       m06  2008-02-19
# 49      91503  127_S_1427       m06  2008-02-19
# 50      91504  127_S_1427       m06  2008-02-19
# 51      91505  127_S_1427       m06  2008-02-19
# 52      91506  127_S_1427       m06  2008-02-19
# 53      91507  127_S_1427       m06  2008-02-19
# 54      91508  127_S_1427       m06  2008-02-19
# 55      91509  127_S_1427       m06  2008-02-19
# ...

# %%
df_viscode_merge = df_patients.merge(df_images, left_on=['VISCODE', 'PTID'] ,right_on=['mri_visit', 'subject_id'], how='left')

# %%
df_viscode_merge
# Out:
#        PHASE         PTID    RID VISCODE VISCODE2    EXAMDATE  DIAGNOSIS  \
# 0      ADNI1   011_S_0002      2      bl       bl  2005-09-29        1.0
# 1      ADNI1   011_S_0003      3      bl       bl  2005-09-30        3.0
# 2      ADNI1   011_S_0005      5      bl       bl  2005-09-30        1.0
# 3      ADNI1   011_S_0008      8      bl       bl  2005-09-30        1.0
# 4      ADNI1   022_S_0007      7      bl       bl  2005-10-06        3.0
# ...      ...          ...    ...     ...      ...         ...        ...
# 98001  ADNI4   137_S_4351   4351  4_init     m156  2024-10-16        2.0
# 98002  ADNI4   067_S_6525   6525  4_init      m66  2024-10-21        1.0
# 98003  ADNI4   137_S_6693   6693  4_init      m60  2024-10-18        3.0
# 98004  ADNI4  052_S_10307  10307    4_sc       sc  2024-10-21        1.0
# 98005  ADNI4  014_S_10317  10317    4_sc       sc  2024-10-23        1.0
#
#        DXNORM  DXNODEP  DXMCI  ... mri_flip_angle  mri_acq_plane  mri_width  \
# ...

# %%
null_values = df_viscode_merge['mri_mfr'].isnull().sum()

total = len(df_viscode_merge['mri_mfr'])

print('Total values:', total)

print('Null values:', null_values)

print('Matched values: ', (total - null_values))
# Out:
# Total values: 98006
# Null values: 5183
# Matched values:  92823

# %%
df_viscode_merge.value_counts(subset = ['PTID', 'VISCODE'])
# Out:
# PTID        VISCODE
# 051_S_1131  m36        42
# 130_S_0449  m12        40
# 128_S_1242  m12        36
# 051_S_5285  init       32
# 035_S_7050  4_init     30
#                        ..
# 067_S_4184  v31         1
#             v03         1
#             v01         1
# 007_S_4488  v03         1
# 002_S_0295  bl          1
# Name: count, Length: 14147, dtype: int64
