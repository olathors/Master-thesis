# %%
import os
import pandas as pd
import numpy as np
from operator import itemgetter
from datetime import date

# %%
DXSUM = pd.read_csv("data/All_Subjects_DXSUM_24Oct2024.csv")
DXSUM[0:100]
# Out:
#     PHASE        PTID  RID VISCODE VISCODE2    EXAMDATE  DIAGNOSIS  DXNORM  \
# 0   ADNI1  011_S_0002    2      bl       bl  2005-09-29        1.0     1.0
# 1   ADNI1  011_S_0003    3      bl       bl  2005-09-30        3.0    -4.0
# 2   ADNI1  011_S_0005    5      bl       bl  2005-09-30        1.0     1.0
# 3   ADNI1  011_S_0008    8      bl       bl  2005-09-30        1.0     1.0
# 4   ADNI1  022_S_0007    7      bl       bl  2005-10-06        3.0    -4.0
# ..    ...         ...  ...     ...      ...         ...        ...     ...
# 95  ADNI1  068_S_0210  210      bl       bl  2006-03-02        1.0     1.0
# 96  ADNI1  068_S_0127  127      bl       bl  2006-03-02        1.0     1.0
# 97  ADNI1  032_S_0187  187      bl       bl  2006-03-02        2.0    -4.0
# 98  ADNI1  021_S_0159  159      bl       bl  2006-03-03        1.0     1.0
# 99  ADNI1  114_S_0228  228      bl       bl  2006-03-03        3.0    -4.0
#
#     DXNODEP  DXMCI  ... DXODES  DXCONFID   ID  SITEID    USERDATE  USERDATE2  \
# 0      -4.0   -4.0  ...   -4.0       4.0    2     107  2005-10-01        NaN
# 1      -4.0   -4.0  ...   -4.0       3.0    4     107  2005-10-01        NaN
# 2      -4.0   -4.0  ...   -4.0       4.0    6     107  2005-10-01        NaN
# 3      -4.0   -4.0  ...   -4.0       3.0    8     107  2005-10-01        NaN
# 4      -4.0   -4.0  ...   -4.0       4.0   10      10  2005-10-06        NaN
# ..      ...    ...  ...    ...       ...  ...     ...         ...        ...
# 95     -4.0   -4.0  ...   -4.0       3.0  192      33  2006-03-02        NaN
# 96     -4.0   -4.0  ...   -4.0       3.0  194      33  2006-03-02        NaN
# 97     -4.0    1.0  ...   -4.0       4.0  196      16  2006-03-02        NaN
# 98     -4.0   -4.0  ...   -4.0       4.0  198       9  2006-03-03        NaN
# 99     -4.0   -4.0  ...   -4.0       4.0  200      87  2006-03-06        NaN
#
#     DD_CRF_VERSION_LABEL  LANGUAGE_CODE HAS_QC_ERROR           update_stamp
# 0                    NaN            NaN          NaN  2005-10-01 00:00:00.0
# 1                    NaN            NaN          NaN  2005-10-01 00:00:00.0
# 2                    NaN            NaN          NaN  2005-10-01 00:00:00.0
# 3                    NaN            NaN          NaN  2005-10-01 00:00:00.0
# 4                    NaN            NaN          NaN  2005-10-06 00:00:00.0
# ..                   ...            ...          ...                    ...
# 95                   NaN            NaN          NaN  2006-03-02 00:00:00.0
# 96                   NaN            NaN          NaN  2006-03-02 00:00:00.0
# 97                   NaN            NaN          NaN  2006-03-02 00:00:00.0
# 98                   NaN            NaN          NaN  2006-03-03 00:00:00.0
# 99                   NaN            NaN          NaN  2006-03-06 00:00:00.0
#
# [100 rows x 41 columns]

# %% [markdown]
# **Amount of patients**

# %%
DXSUM['PTID'].unique().shape
# Out:
# (3220,)

# %% [markdown]
# **Creating a dictionary where the keys are patient IDs, and the values are relevant information abaout visits.**

# %%
patient_dict = {}

for index, row in DXSUM.iterrows():
    
    if len(str(row['EXAMDATE'])) > 3:
        datex = [int(x) for x in row['EXAMDATE'].split("-")]

        if row['PTID'] in patient_dict:


            patient_dict[row['PTID']].append([row['VISCODE'], date(datex[0], datex[1], datex[2]), row['DIAGNOSIS']])
        else:

            patient_dict[row['PTID']] = [[row['VISCODE'], date(datex[0], datex[1], datex[2]), row['DIAGNOSIS']]]

np.save("data/patient_dict.npy", patient_dict)

# %%
patient_dict
for key in patient_dict:
    array = patient_dict[key]
    sorted(array, key=itemgetter(1))
patient_dict
# Out:
# {'011_S_0002': [['bl', datetime.date(2005, 9, 29), 1.0],
#   ['m06', datetime.date(2006, 3, 6), 1.0],
#   ['m36', datetime.date(2008, 8, 27), 1.0],
#   ['m60', datetime.date(2010, 9, 27), 1.0],
#   ['v06', datetime.date(2011, 9, 19), 1.0],
#   ['v11', datetime.date(2012, 10, 4), 2.0],
#   ['v21', datetime.date(2013, 9, 23), 1.0],
#   ['v41', datetime.date(2015, 10, 20), 1.0],
#   ['v51', datetime.date(2016, 10, 3), 2.0],
#   ['init', datetime.date(2017, 11, 1), 2.0]],
#  '011_S_0003': [['bl', datetime.date(2005, 9, 30), 3.0],
#   ['m06', datetime.date(2006, 3, 13), 3.0],
#   ['m12', datetime.date(2006, 9, 13), 3.0],
#   ['m24', datetime.date(2007, 9, 12), 3.0]],
#  '011_S_0005': [['bl', datetime.date(2005, 9, 30), 1.0],
#   ['m06', datetime.date(2006, 3, 9), 1.0],
#   ['m12', datetime.date(2006, 9, 6), 1.0],
#   ['m24', datetime.date(2007, 9, 7), 1.0],
#   ['m36', datetime.date(2008, 9, 10), 1.0]],
#  '011_S_0008': [['bl', datetime.date(2005, 9, 30), 1.0],
#   ['m06', datetime.date(2006, 3, 20), 1.0],
#   ['m12', datetime.date(2006, 9, 20), 1.0],
#   ['m36', datetime.date(2008, 9, 9), 1.0],
#   ['m48', datetime.date(2009, 10, 13), 1.0],
#   ['m60', datetime.date(2010, 10, 1), 1.0],
#   ['v06', datetime.date(2011, 9, 29), 1.0],
#   ['v11', datetime.date(2012, 10, 4), 1.0],
#   ['v21', datetime.date(2013, 9, 23), 1.0],
#   ['v41', datetime.date(2015, 11, 10), 2.0]],
#  '022_S_0007': [['bl', datetime.date(2005, 10, 6), 3.0],
#   ['m06', datetime.date(2006, 4, 13), 3.0],
#   ['m12', datetime.date(2006, 10, 12), 3.0],
#   ['m24', datetime.date(2007, 10, 11), 3.0]],
#  '100_S_0015': [['bl', datetime.date(2005, 10, 18), 1.0],
#   ['m06', datetime.date(2006, 4, 20), 1.0],
#   ['m12', datetime.date(2006, 10, 18), 1.0],
#   ['m24', datetime.date(2007, 10, 16), 1.0],
#   ['m36', datetime.date(2008, 10, 29), 1.0],
#   ['v06', datetime.date(2011, 11, 29), 2.0]],
#  '023_S_0030': [['bl', datetime.date(2005, 10, 20), 2.0],
#   ['m06', datetime.date(2006, 4, 13), 3.0],
#   ['m12', datetime.date(2006, 10, 12), 3.0],
#   ['m18', datetime.date(2007, 5, 7), 3.0],
#   ['m24', datetime.date(2007, 11, 13), 3.0],
#   ['m36', datetime.date(2008, 11, 26), 3.0]],
#  '023_S_0031': [['bl', datetime.date(2005, 10, 24), 1.0],
#   ['m06', datetime.date(2006, 4, 18), 1.0],
#   ['m12', datetime.date(2006, 10, 30), 1.0],
#   ['m24', datetime.date(2007, 11, 20), 1.0],
#   ['m36', datetime.date(2008, 12, 2), 1.0],
#   ['m48', datetime.date(2009, 10, 23), 1.0],
#   ['m60', datetime.date(2010, 12, 10), 1.0],
#   ['v06', datetime.date(2011, 10, 23), 1.0],
#   ['v11', datetime.date(2012, 9, 25), 1.0],
#   ['v21', datetime.date(2013, 10, 21), 1.0],
#   ['v41', datetime.date(2016, 4, 11), 1.0],
#   ['init', datetime.date(2018, 4, 25), 1.0],
#   ['y1', datetime.date(2019, 5, 1), 1.0]],
#  '011_S_0016': [['bl', datetime.date(2005, 10, 25), 1.0],
#   ['m06', datetime.date(2006, 4, 12), 1.0],
#   ['m12', datetime.date(2006, 10, 11), 1.0],
#   ['m24', datetime.date(2007, 9, 17), 1.0],
#   ['m36', datetime.date(2008, 10, 17), 1.0]],
#  '011_S_0021': [['bl', datetime.date(2005, 11, 1), 1.0],
#   ['m06', datetime.date(2006, 4, 24), 1.0],
#   ['m12', datetime.date(2006, 11, 1), 1.0],
#   ['m24', datetime.date(2007, 10, 30), 1.0],
#   ['m36', datetime.date(2008, 10, 22), 1.0],
#   ['m60', datetime.date(2010, 10, 18), 1.0],
#   ['v06', datetime.date(2011, 10, 19), 1.0],
#   ['v11', datetime.date(2012, 10, 11), 1.0],
#   ['v21', datetime.date(2013, 11, 6), 1.0],
#   ['v41', datetime.date(2015, 11, 10), 1.0],
#   ['init', datetime.date(2018, 2, 26), 1.0],
#   ['4_init', datetime.date(2024, 7, 29), 1.0]],
#  '011_S_0022': [['bl', datetime.date(2005, 11, 1), 1.0],
#   ['m06', datetime.date(2006, 4, 20), 1.0],
#   ['m12', datetime.date(2006, 10, 19), 1.0],
#   ['m24', datetime.date(2007, 10, 22), 2.0]],
#  '022_S_0014': [['bl', datetime.date(2005, 11, 4), 1.0],
#   ['m06', datetime.date(2006, 5, 2), 1.0],
#   ['m12', datetime.date(2006, 11, 27), 1.0],
#   ['m24', datetime.date(2007, 11, 27), 1.0],
#   ['m36', datetime.date(2008, 11, 5), 1.0]],
#  '100_S_0035': [['bl', datetime.date(2005, 11, 9), 1.0],
#   ['m06', datetime.date(2006, 5, 23), 1.0],
#   ['m12', datetime.date(2007, 2, 28), 1.0],
#   ['m24', datetime.date(2007, 11, 2), 1.0],
#   ['m36', datetime.date(2008, 11, 24), 1.0],
#   ['m60', datetime.date(2011, 3, 31), 2.0]],
#  '023_S_0042': [['bl', datetime.date(2005, 11, 10), 2.0],
#   ['m06', datetime.date(2006, 5, 2), 2.0],
#   ['m12', datetime.date(2006, 11, 9), 3.0],
#   ['m18', datetime.date(2007, 5, 10), 3.0],
#   ['m24', datetime.date(2007, 12, 3), 3.0],
#   ['m36', datetime.date(2008, 12, 6), 3.0],
#   ['m48', datetime.date(2010, 3, 18), 3.0],
#   ['v06', datetime.date(2011, 4, 20), 3.0],
#   ['v11', datetime.date(2012, 1, 6), 3.0],
#   ['v21', datetime.date(2013, 2, 5), 3.0],
#   ['v31', datetime.date(2013, 12, 4), 3.0]],
#  '067_S_0029': [['bl', datetime.date(2005, 11, 11), 3.0],
#   ['m06', datetime.date(2006, 5, 22), 3.0],
#   ['m12', datetime.date(2006, 12, 5), 3.0],
#   ['m24', datetime.date(2008, 9, 29), 3.0]],
#  '007_S_0041': [['bl', datetime.date(2005, 11, 14), 2.0],
#   ['m06', datetime.date(2006, 5, 15), 2.0],
#   ['m12', datetime.date(2006, 11, 28), 2.0],
#   ['m18', datetime.date(2007, 5, 14), 3.0],
#   ['m24', datetime.date(2007, 11, 14), 3.0],
#   ['m36', datetime.date(2008, 11, 13), 3.0],
#   ['m48', datetime.date(2010, 1, 14), 3.0]],
#  '022_S_0004': [['bl', datetime.date(2005, 11, 8), 2.0],
#   ['m06', datetime.date(2006, 5, 2), 2.0],
#   ['m12', datetime.date(2006, 11, 14), 2.0],
#   ['m18', datetime.date(2007, 5, 14), 2.0],
#   ['m36', datetime.date(2008, 11, 18), 2.0]],
#  '022_S_0044': [['bl', datetime.date(2005, 11, 30), 2.0],
#   ['m06', datetime.date(2006, 6, 9), 2.0],
#   ['m12', datetime.date(2007, 1, 12), 2.0]],
#  '100_S_0006': [['bl', datetime.date(2005, 12, 1), 2.0],
#   ['m06', datetime.date(2006, 6, 7), 2.0],
#   ['m12', datetime.date(2007, 1, 9), 2.0],
#   ['m18', datetime.date(2007, 6, 8), 2.0],
#   ['m24', datetime.date(2007, 11, 19), 2.0],
#   ['m36', datetime.date(2008, 12, 15), 2.0]],
#  '022_S_0066': [['bl', datetime.date(2005, 12, 7), 1.0],
#   ['m06', datetime.date(2006, 6, 2), 1.0],
#   ['m12', datetime.date(2007, 1, 12), 1.0],
#   ['m24', datetime.date(2007, 12, 14), 1.0],
#   ['m36', datetime.date(2009, 2, 6), 1.0]],
#  '067_S_0019': [['bl', datetime.date(2005, 12, 8), 1.0],
#   ['m06', datetime.date(2006, 6, 13), 1.0],
#   ['m12', datetime.date(2007, 1, 9), 1.0],
#   ['m36', datetime.date(2008, 12, 15), 1.0]],
#  '023_S_0058': [['bl', datetime.date(2005, 12, 12), 1.0],
#   ['m06', datetime.date(2006, 6, 13), 1.0],
#   ['m12', datetime.date(2006, 12, 19), 1.0],
#   ['m24', datetime.date(2007, 12, 11), 1.0],
#   ['m36', datetime.date(2008, 12, 9), 1.0],
#   ['m48', datetime.date(2010, 3, 21), 1.0],
#   ['v06', datetime.date(2011, 5, 13), 1.0],
#   ['v11', datetime.date(2012, 4, 3), 1.0],
#   ['v31', datetime.date(2013, 12, 22), 1.0]],
#  '007_S_0068': [['bl', datetime.date(2005, 12, 14), 1.0],
#   ['m06', datetime.date(2006, 6, 19), 1.0],
#   ['m12', datetime.date(2006, 11, 29), 1.0],
#   ['m24', datetime.date(2007, 12, 10), 1.0],
#   ['m36', datetime.date(2008, 12, 2), 1.0],
#   ['m48', datetime.date(2010, 1, 20), 1.0],
#   ['m60', datetime.date(2011, 1, 17), 1.0]],
#  '023_S_0061': [['bl', datetime.date(2005, 12, 15), 1.0],
#   ['m06', datetime.date(2006, 6, 15), 1.0],
#   ['m12', datetime.date(2006, 12, 7), 1.0],
#   ['m24', datetime.date(2007, 12, 13), 1.0],
#   ['m36', datetime.date(2008, 12, 20), 1.0],
#   ['m48', datetime.date(2010, 2, 27), 1.0],
#   ['m60', datetime.date(2011, 2, 8), 1.0],
#   ['v06', datetime.date(2012, 2, 7), 1.0],
#   ['v11', datetime.date(2013, 2, 7), 2.0],
#   ['v21', datetime.date(2014, 1, 4), 3.0],
#   ['v31', datetime.date(2015, 3, 12), 3.0],
#   ['v41', datetime.date(2016, 4, 29), 3.0]],
#  '100_S_0047': [['bl', datetime.date(2005, 12, 15), 1.0],
#   ['m06', datetime.date(2006, 6, 28), 1.0],
#   ['m12', datetime.date(2007, 2, 21), 1.0],
#   ['m24', datetime.date(2007, 12, 12), 1.0],
#   ['m36', datetime.date(2008, 12, 16), 1.0],
#   ['m60', datetime.date(2011, 3, 31), 1.0]],
#  '123_S_0050': [['bl', datetime.date(2005, 12, 2), 2.0],
#   ['m06', datetime.date(2006, 6, 7), 3.0],
#   ['m12', datetime.date(2006, 12, 7), 3.0],
#   ['m18', datetime.date(2007, 6, 20), 3.0],
#   ['m24', datetime.date(2007, 12, 13), 3.0],
#   ['m36', datetime.date(2008, 11, 18), 3.0]],
#  '067_S_0038': [['bl', datetime.date(2005, 12, 16), 2.0],
#   ['m06', datetime.date(2006, 6, 23), 2.0],
#   ['m12', datetime.date(2006, 12, 19), 2.0]],
#  '035_S_0033': [['bl', datetime.date(2005, 12, 9), 2.0],
#   ['m06', datetime.date(2006, 5, 26), 2.0],
#   ['m12', datetime.date(2007, 1, 17), 2.0],
#   ['m18', datetime.date(2007, 6, 21), 2.0],
#   ['m24', datetime.date(2007, 12, 10), 2.0],
#   ['m36', datetime.date(2009, 1, 12), 2.0]],
#  '035_S_0048': [['bl', datetime.date(2005, 12, 19), 1.0],
#   ['m06', datetime.date(2006, 6, 15), 1.0],
#   ['m12', datetime.date(2007, 2, 27), 1.0],
#   ['m24', datetime.date(2007, 12, 20), 1.0],
#   ['m36', datetime.date(2009, 1, 23), 1.0]],
#  '067_S_0056': [['bl', datetime.date(2005, 12, 22), 1.0],
#   ['m06', datetime.date(2006, 8, 10), 1.0],
#   ['m12', datetime.date(2007, 1, 2), 1.0],
#   ['m36', datetime.date(2008, 12, 16), 1.0],
#   ['m48', datetime.date(2010, 5, 7), 1.0],
#   ['m60', datetime.date(2010, 12, 14), 1.0],
#   ['v06', datetime.date(2011, 12, 16), 1.0],
#   ['v11', datetime.date(2012, 12, 20), 2.0],
#   ['v21', datetime.date(2014, 2, 6), 1.0],
#   ['v31', datetime.date(2015, 1, 7), 1.0],
#   ['v41', datetime.date(2016, 1, 20), 1.0],
#   ['init', datetime.date(2018, 2, 21), 2.0],
#   ['y1', datetime.date(2019, 2, 5), 2.0],
#   ['y2', datetime.date(2019, 12, 11), 2.0]],
#  '099_S_0051': [['bl', datetime.date(2005, 12, 29), 2.0],
#   ['m06', datetime.date(2006, 9, 1), 2.0],
#   ['m12', datetime.date(2007, 2, 1), 2.0],
#   ['m18', datetime.date(2007, 7, 9), 2.0],
#   ['m24', datetime.date(2007, 12, 13), 2.0],
#   ['m36', datetime.date(2008, 12, 12), 2.0],
#   ['v06', datetime.date(2011, 8, 8), 3.0],
#   ['v11', datetime.date(2012, 12, 13), 3.0],
#   ['v21', datetime.date(2013, 11, 26), 3.0],
#   ['v31', datetime.date(2015, 2, 4), 3.0],
#   ['v41', datetime.date(2016, 1, 27), 3.0]],
#  '099_S_0040': [['bl', datetime.date(2005, 12, 29), 1.0],
#   ['m06', datetime.date(2006, 9, 1), 1.0],
#   ['m12', datetime.date(2007, 3, 9), 1.0],
#   ['m24', datetime.date(2007, 12, 24), 1.0],
#   ['m36', datetime.date(2009, 1, 16), 1.0]],
#  '011_S_0010': [['bl', datetime.date(2005, 11, 10), 3.0],
#   ['m06', datetime.date(2006, 5, 9), 3.0],
#   ['m12', datetime.date(2006, 11, 10), 3.0],
#   ['m24', datetime.date(2007, 11, 7), 3.0]],
#  '011_S_0023': [['bl', datetime.date(2005, 11, 8), 1.0],
#   ['m06', datetime.date(2006, 5, 8), 1.0],
#   ['m12', datetime.date(2006, 11, 21), 1.0],
#   ['m24', datetime.date(2007, 11, 20), 1.0],
#   ['m36', datetime.date(2008, 11, 25), 1.0],
#   ['m48', datetime.date(2010, 1, 6), 1.0],
#   ['m60', datetime.date(2011, 1, 6), 1.0],
#   ['v06', datetime.date(2011, 12, 22), 1.0],
#   ['v11', datetime.date(2013, 1, 8), 1.0],
#   ['v21', datetime.date(2014, 1, 17), 1.0]],
#  '011_S_0053': [['bl', datetime.date(2005, 11, 29), 3.0],
#   ['m06', datetime.date(2006, 5, 30), 3.0],
#   ['m12', datetime.date(2006, 11, 29), 3.0],
#   ['m24', datetime.date(2007, 11, 29), 3.0]],
#  '099_S_0054': [['bl', datetime.date(2005, 12, 29), 2.0],
#   ['m06', datetime.date(2006, 9, 1), 2.0],
#   ['m12', datetime.date(2007, 3, 9), 3.0],
#   ['m18', datetime.date(2007, 10, 9), 3.0],
#   ['m24', datetime.date(2007, 12, 28), 3.0],
#   ['m36', datetime.date(2008, 12, 12), 3.0]],
#  '123_S_0091': [['bl', datetime.date(2006, 1, 3), 3.0],
#   ['m06', datetime.date(2006, 6, 27), 3.0],
#   ['m12', datetime.date(2007, 1, 16), 3.0],
#   ['m24', datetime.date(2008, 1, 14), 3.0]],
#  '007_S_0101': [['bl', datetime.date(2006, 1, 5), 2.0],
#   ['m06', datetime.date(2006, 7, 6), 2.0],
#   ['m12', datetime.date(2007, 1, 29), 2.0],
#   ['m18', datetime.date(2007, 7, 31), 2.0],
#   ['m24', datetime.date(2008, 1, 8), 3.0],
#   ['m36', datetime.date(2009, 1, 8), 3.0],
#   ['m48', datetime.date(2010, 2, 4), 3.0],
#   ['v06', datetime.date(2012, 3, 19), 3.0],
#   ['v11', datetime.date(2013, 4, 9), 3.0]],
#  '123_S_0094': [['bl', datetime.date(2006, 1, 5), 3.0],
#   ['m06', datetime.date(2006, 6, 26), 3.0],
#   ['m12', datetime.date(2007, 1, 23), 3.0],
#   ['m24', datetime.date(2008, 1, 12), 3.0]],
#  '027_S_0074': [['bl', datetime.date(2006, 1, 10), 1.0],
#   ['m06', datetime.date(2006, 7, 7), 1.0],
#   ['m12', datetime.date(2007, 1, 12), 1.0],
#   ['m24', datetime.date(2008, 1, 9), 1.0],
#   ['m36', datetime.date(2009, 1, 15), 1.0],
#   ['m48', datetime.date(2010, 1, 7), 1.0],
#   ['m60', datetime.date(2010, 12, 27), 1.0],
#   ['m72', datetime.date(2012, 1, 5), 1.0],
#   ['v06', datetime.date(2012, 12, 13), 1.0],
#   ['v11', datetime.date(2014, 1, 16), 1.0],
#   ['v21', datetime.date(2015, 2, 5), 1.0],
#   ['init', datetime.date(2017, 1, 17), 1.0],
#   ['y2', datetime.date(2019, 1, 22), 1.0],
#   ['y4', datetime.date(2021, 1, 11), 1.0],
#   ['4_init', datetime.date(2024, 5, 28), 1.0]],
#  '067_S_0059': [['bl', datetime.date(2006, 1, 10), 1.0],
#   ['m06', datetime.date(2006, 8, 10), 1.0],
#   ['m12', datetime.date(2007, 1, 2), 1.0],
#   ['m36', datetime.date(2008, 12, 16), 1.0],
#   ['m48', datetime.date(2010, 5, 7), 1.0],
#   ['m60', datetime.date(2010, 12, 10), 1.0],
#   ['v06', datetime.date(2011, 12, 16), 1.0],
#   ['v11', datetime.date(2012, 12, 20), 2.0],
#   ['v21', datetime.date(2014, 2, 6), 1.0],
#   ['v31', datetime.date(2015, 1, 7), 1.0],
#   ['v41', datetime.date(2016, 1, 20), 1.0],
#   ['init', datetime.date(2018, 2, 21), 2.0],
#   ['y2', datetime.date(2020, 1, 8), 2.0]],
#  '023_S_0078': [['bl', datetime.date(2006, 1, 12), 3.0],
#   ['m06', datetime.date(2006, 7, 11), 3.0],
#   ['m12', datetime.date(2007, 1, 11), 3.0],
#   ['m18', datetime.date(2007, 7, 24), 3.0]],
#  '067_S_0076': [['bl', datetime.date(2006, 1, 13), 3.0],
#   ['m06', datetime.date(2006, 7, 14), 3.0],
#   ['m12', datetime.date(2007, 3, 28), 3.0],
#   ['m24', datetime.date(2008, 10, 30), 3.0]],
#  '100_S_0069': [['bl', datetime.date(2006, 1, 17), 1.0],
#   ['m06', datetime.date(2006, 7, 12), 1.0],
#   ['m12', datetime.date(2007, 2, 21), 1.0],
#   ['m24', datetime.date(2008, 1, 16), 1.0],
#   ['m36', datetime.date(2009, 1, 21), 1.0],
#   ['m60', datetime.date(2011, 2, 18), 1.0],
#   ['v06', datetime.date(2012, 1, 23), 2.0],
#   ['v21', datetime.date(2014, 3, 13), 1.0],
#   ['v31', datetime.date(2015, 1, 30), 1.0],
#   ['v41', datetime.date(2016, 7, 19), 1.0],
#   ['init', datetime.date(2018, 2, 7), 2.0],
#   ['y1', datetime.date(2019, 1, 29), 2.0],
#   ['y2', datetime.date(2020, 2, 12), 2.0],
#   ['4_init', datetime.date(2024, 4, 8), 2.0]],
#  '099_S_0060': [['bl', datetime.date(2006, 1, 17), 2.0],
#   ['m06', datetime.date(2006, 9, 1), 2.0],
#   ['m12', datetime.date(2007, 3, 9), 2.0],
#   ['m18', datetime.date(2007, 10, 9), 2.0]],
#  '010_S_0067': [['bl', datetime.date(2006, 1, 18), 1.0],
#   ['m06', datetime.date(2006, 8, 14), 1.0],
#   ['m12', datetime.date(2007, 1, 23), 1.0],
#   ['m24', datetime.date(2008, 1, 22), 1.0]],
#  '018_S_0057': [['bl', datetime.date(2006, 1, 18), 2.0],
#   ['m06', datetime.date(2006, 8, 21), 2.0],
#   ['m12', datetime.date(2007, 1, 9), 2.0],
#   ['m18', datetime.date(2007, 10, 29), 3.0],
#   ['m24', datetime.date(2008, 2, 8), 3.0],
#   ['m36', datetime.date(2009, 4, 3), 3.0]],
#  '032_S_0095': [['bl', datetime.date(2006, 1, 19), 1.0],
#   ['m06', datetime.date(2006, 7, 7), 1.0],
#   ['m12', datetime.date(2007, 1, 24), 1.0],
#   ['m24', datetime.date(2008, 1, 9), 1.0]],
#  '018_S_0080': [['bl', datetime.date(2006, 1, 18), 2.0],
#   ['m06', datetime.date(2006, 7, 20), 2.0],
#   ['m12', datetime.date(2007, 1, 9), 2.0],
#   ['m18', datetime.date(2007, 7, 26), 2.0],
#   ['m24', datetime.date(2008, 2, 8), 2.0],
#   ['m36', datetime.date(2009, 1, 30), 2.0],
#   ['m48', datetime.date(2010, 6, 8), 3.0]],
#  '018_S_0055': [['bl', datetime.date(2006, 1, 18), 1.0],
#   ['m06', datetime.date(2006, 7, 18), 1.0],
#   ['m12', datetime.date(2007, 2, 28), 1.0],
#   ['m36', datetime.date(2008, 10, 13), 1.0],
#   ['m48', datetime.date(2011, 5, 6), 2.0],
#   ['v06', datetime.date(2012, 5, 2), 2.0],
#   ['v11', datetime.date(2013, 7, 22), 2.0],
#   ['v21', datetime.date(2014, 6, 26), 2.0],
#   ['v31', datetime.date(2015, 7, 10), 2.0]],
#  '023_S_0084': [['bl', datetime.date(2006, 1, 24), 3.0],
#   ['m06', datetime.date(2006, 7, 27), 3.0],
#   ['m12', datetime.date(2007, 1, 25), 3.0],
#   ['m24', datetime.date(2008, 1, 25), 3.0],
#   ['m36', datetime.date(2009, 3, 19), 3.0],
#   ['m48', datetime.date(2010, 3, 25), 3.0]],
#  '123_S_0072': [['bl', datetime.date(2006, 1, 17), 1.0],
#   ['m06', datetime.date(2006, 7, 19), 1.0],
#   ['m12', datetime.date(2007, 1, 18), 1.0],
#   ['m24', datetime.date(2008, 1, 24), 1.0],
#   ['m36', datetime.date(2008, 2, 11), 1.0],
#   ['m48', datetime.date(2010, 1, 27), 1.0],
#   ['m60', datetime.date(2011, 1, 11), 1.0],
#   ['v06', datetime.date(2012, 1, 10), 1.0],
#   ['v11', datetime.date(2013, 1, 8), 1.0],
#   ['v21', datetime.date(2014, 1, 22), 1.0],
#   ['v41', datetime.date(2016, 3, 2), 1.0],
#   ['init', datetime.date(2017, 10, 31), 1.0],
#   ['y2', datetime.date(2019, 10, 16), 1.0],
#   ['y4', datetime.date(2021, 10, 12), 1.0],
#   ['4_init', datetime.date(2024, 8, 12), 1.0]],
#  '023_S_0081': [['bl', datetime.date(2006, 1, 25), 1.0],
#   ['m06', datetime.date(2006, 7, 25), 1.0],
#   ['m12', datetime.date(2007, 1, 19), 1.0],
#   ['m24', datetime.date(2008, 1, 16), 1.0],
#   ['m36', datetime.date(2009, 2, 11), 1.0],
#   ['m48', datetime.date(2010, 3, 11), 1.0]],
#  '023_S_0093': [['bl', datetime.date(2006, 1, 26), 3.0],
#   ['m06', datetime.date(2006, 8, 3), 3.0],
#   ['m12', datetime.date(2007, 2, 13), 3.0],
#   ['m24', datetime.date(2008, 1, 29), 3.0]],
#  '023_S_0083': [['bl', datetime.date(2006, 1, 19), 3.0],
#   ['m06', datetime.date(2006, 7, 6), 3.0],
#   ['m12', datetime.date(2007, 1, 9), 3.0],
#   ['m24', datetime.date(2008, 2, 1), 3.0]],
#  '067_S_0045': [['bl', datetime.date(2006, 1, 26), 2.0],
#   ['m06', datetime.date(2006, 7, 13), 2.0],
#   ['m12', datetime.date(2007, 3, 28), 3.0]],
#  '068_S_0109': [['bl', datetime.date(2006, 2, 2), 3.0],
#   ['m06', datetime.date(2006, 9, 11), 3.0],
#   ['m12', datetime.date(2007, 4, 25), 3.0],
#   ['m24', datetime.date(2008, 6, 5), 3.0]],
#  '023_S_0139': [['bl', datetime.date(2006, 2, 2), 3.0],
#   ['m06', datetime.date(2006, 7, 28), 3.0],
#   ['m12', datetime.date(2007, 2, 9), 3.0],
#   ['m24', datetime.date(2008, 3, 5), 3.0],
#   ['m36', datetime.date(2009, 4, 10), 3.0],
#   ['m48', datetime.date(2010, 3, 19), 3.0]],
#  '123_S_0106': [['bl', datetime.date(2006, 2, 1), 1.0],
#   ['m06', datetime.date(2006, 8, 1), 1.0],
#   ['m12', datetime.date(2007, 1, 30), 1.0],
#   ['m24', datetime.date(2008, 2, 6), 1.0],
#   ['m36', datetime.date(2009, 1, 20), 1.0],
#   ['m48', datetime.date(2010, 1, 21), 1.0],
#   ['m60', datetime.date(2011, 1, 24), 2.0],
#   ['v06', datetime.date(2012, 1, 25), 2.0],
#   ['v11', datetime.date(2013, 1, 22), 2.0],
#   ['v21', datetime.date(2014, 1, 28), 2.0],
#   ['v31', datetime.date(2015, 3, 5), 3.0],
#   ['v41', datetime.date(2016, 3, 5), 3.0],
#   ['init', datetime.date(2017, 6, 28), 3.0],
#   ['y1', datetime.date(2018, 10, 17), 3.0],
#   ['y2', datetime.date(2019, 10, 10), 3.0]],
#  '018_S_0087': [['bl', datetime.date(2006, 2, 3), 2.0],
#   ['m06', datetime.date(2006, 8, 24), 2.0],
#   ['m12', datetime.date(2007, 2, 19), 2.0],
#   ['m18', datetime.date(2007, 8, 1), 2.0]],
#  '022_S_0096': [['bl', datetime.date(2006, 2, 6), 1.0],
#   ['m06', datetime.date(2006, 7, 12), 1.0],
#   ['m12', datetime.date(2007, 1, 30), 1.0],
#   ['m24', datetime.date(2008, 2, 29), 1.0],
#   ['m36', datetime.date(2009, 2, 10), 1.0],
#   ['m48', datetime.date(2010, 2, 12), 1.0],
#   ['m60', datetime.date(2011, 2, 2), 1.0],
#   ['v06', datetime.date(2012, 2, 7), 1.0],
#   ['v11', datetime.date(2013, 2, 26), 1.0],
#   ['v21', datetime.date(2014, 2, 10), 1.0],
#   ['v41', datetime.date(2016, 4, 6), 1.0],
#   ['init', datetime.date(2017, 3, 27), 1.0],
#   ['y4', datetime.date(2021, 4, 5), 1.0]],
#  '018_S_0103': [['bl', datetime.date(2006, 2, 6), 2.0],
#   ['m06', datetime.date(2006, 8, 10), 2.0]],
#  '018_S_0043': [['bl', datetime.date(2006, 2, 3), 1.0],
#   ['m06', datetime.date(2006, 8, 10), 1.0],
#   ['m12', datetime.date(2007, 2, 7), 1.0],
#   ['m24', datetime.date(2008, 3, 4), 1.0],
#   ['m36', datetime.date(2009, 2, 13), 1.0],
#   ['m48', datetime.date(2010, 2, 19), 1.0]],
#  '127_S_0112': [['bl', datetime.date(2006, 2, 1), 2.0],
#   ['m06', datetime.date(2006, 7, 31), 1.0],
#   ['m12', datetime.date(2007, 2, 13), 2.0],
#   ['m18', datetime.date(2007, 8, 6), 2.0],
#   ['m24', datetime.date(2008, 1, 31), 1.0],
#   ['m36', datetime.date(2009, 3, 4), 1.0],
#   ['m48', datetime.date(2010, 2, 9), 1.0],
#   ['m60', datetime.date(2011, 6, 17), 2.0],
#   ['v06', datetime.date(2012, 2, 29), 1.0],
#   ['v11', datetime.date(2013, 3, 5), 2.0],
#   ['v21', datetime.date(2014, 2, 28), 2.0],
#   ['v31', datetime.date(2015, 6, 26), 2.0],
#   ['v41', datetime.date(2016, 3, 15), 3.0],
#   ['init', datetime.date(2017, 12, 5), 3.0],
#   ['y1', datetime.date(2018, 8, 28), 3.0]],
#  '022_S_0130': [['bl', datetime.date(2006, 2, 7), 1.0],
#   ['m06', datetime.date(2006, 9, 15), 1.0],
#   ['m12', datetime.date(2007, 2, 21), 1.0],
#   ['m24', datetime.date(2008, 2, 15), 1.0],
#   ['m36', datetime.date(2009, 2, 12), 1.0],
#   ['m48', datetime.date(2010, 6, 9), 1.0],
#   ['m60', datetime.date(2011, 5, 5), 1.0],
#   ['v06', datetime.date(2012, 5, 15), 1.0],
#   ['v11', datetime.date(2013, 5, 3), 1.0],
#   ['v21', datetime.date(2014, 3, 6), 1.0]],
#  '098_S_0149': [['bl', datetime.date(2006, 2, 8), 3.0],
#   ['m06', datetime.date(2006, 8, 9), 3.0],
#   ['m12', datetime.date(2007, 2, 22), 3.0],
#   ['m24', datetime.date(2008, 2, 11), 3.0]],
#  '067_S_0077': [['bl', datetime.date(2006, 2, 8), 2.0],
#   ['m06', datetime.date(2006, 9, 12), 2.0],
#   ['m12', datetime.date(2007, 3, 26), 3.0],
#   ['m18', datetime.date(2007, 8, 30), 3.0],
#   ['m24', datetime.date(2008, 9, 25), 3.0],
#   ['m36', datetime.date(2009, 1, 29), 3.0]],
#  '099_S_0090': [['bl', datetime.date(2006, 2, 7), 1.0],
#   ['m06', datetime.date(2006, 9, 1), 1.0],
#   ['m12', datetime.date(2007, 3, 9), 1.0],
#   ['m24', datetime.date(2008, 2, 14), 1.0],
#   ['m36', datetime.date(2009, 1, 28), 1.0]],
#  '007_S_0128': [['bl', datetime.date(2006, 2, 6), 2.0],
#   ['m06', datetime.date(2006, 8, 14), 2.0],
#   ['m12', datetime.date(2007, 2, 15), 2.0],
#   ['m18', datetime.date(2007, 8, 22), 3.0],
#   ['m24', datetime.date(2008, 2, 7), 3.0],
#   ['m36', datetime.date(2009, 2, 26), 3.0],
#   ['m48', datetime.date(2010, 2, 24), 3.0],
#   ['m60', datetime.date(2011, 2, 10), 3.0]],
#  '007_S_0070': [['bl', datetime.date(2006, 2, 8), 1.0],
#   ['m06', datetime.date(2006, 9, 13), 1.0],
#   ['m12', datetime.date(2007, 3, 19), 1.0]],
#  '022_S_0129': [['bl', datetime.date(2006, 2, 13), 3.0],
#   ['m06', datetime.date(2006, 9, 15), 3.0],
#   ['m12', datetime.date(2007, 2, 9), 3.0],
#   ['m24', datetime.date(2008, 2, 19), 3.0]],
#  '131_S_0123': [['bl', datetime.date(2006, 2, 14), 1.0],
#   ['m06', datetime.date(2006, 8, 17), 1.0],
#   ['m12', datetime.date(2007, 2, 9), 1.0],
#   ['m24', datetime.date(2008, 3, 20), 1.0],
#   ['m36', datetime.date(2009, 2, 5), 1.0],
#   ['m48', datetime.date(2010, 2, 4), 1.0],
#   ['m60', datetime.date(2011, 3, 8), 1.0],
#   ['v06', datetime.date(2012, 3, 2), 2.0],
#   ['v11', datetime.date(2013, 4, 22), 2.0],
#   ['v21', datetime.date(2014, 3, 10), 3.0],
#   ['v31', datetime.date(2015, 3, 18), 3.0],
#   ['v41', datetime.date(2016, 3, 9), 3.0]],
#  '099_S_0111': [['bl', datetime.date(2006, 2, 10), 2.0],
#   ['m06', datetime.date(2006, 9, 1), 2.0],
#   ['m12', datetime.date(2007, 3, 2), 3.0]],
#  '098_S_0160': [['bl', datetime.date(2006, 2, 14), 2.0],
#   ['m06', datetime.date(2006, 10, 10), 2.0],
#   ['m12', datetime.date(2007, 3, 29), 2.0],
#   ['m18', datetime.date(2007, 8, 14), 2.0],
#   ['m24', datetime.date(2008, 2, 25), 2.0],
#   ['m36', datetime.date(2009, 3, 18), 2.0],
#   ['m48', datetime.date(2010, 2, 18), 2.0],
#   ['v06', datetime.date(2011, 3, 15), 3.0],
#   ['v11', datetime.date(2012, 2, 28), 3.0]],
#  '023_S_0126': [['bl', datetime.date(2006, 2, 16), 2.0],
#   ['m06', datetime.date(2006, 8, 8), 2.0],
#   ['m12', datetime.date(2007, 3, 29), 2.0],
#   ['m18', datetime.date(2007, 8, 15), 2.0],
#   ['m24', datetime.date(2008, 2, 29), 2.0],
#   ['m36', datetime.date(2009, 3, 3), 3.0],
#   ['m48', datetime.date(2010, 3, 4), 3.0],
#   ['m60', datetime.date(2011, 3, 20), 3.0],
#   ['v06', datetime.date(2012, 2, 16), 3.0],
#   ['v11', datetime.date(2013, 4, 9), 3.0],
#   ['v21', datetime.date(2014, 3, 20), 3.0],
#   ['v31', datetime.date(2015, 4, 8), 3.0],
#   ['v41', datetime.date(2016, 4, 22), 3.0]],
#  '027_S_0116': [['bl', datetime.date(2006, 2, 15), 2.0],
#   ['m06', datetime.date(2006, 8, 30), 2.0],
#   ['m12', datetime.date(2007, 2, 6), 2.0],
#   ['m18', datetime.date(2007, 8, 8), 2.0],
#   ['m24', datetime.date(2008, 2, 13), 2.0],
#   ['m36', datetime.date(2009, 2, 26), 2.0],
#   ['m48', datetime.date(2010, 2, 17), 2.0],
#   ['m60', datetime.date(2011, 2, 8), 2.0],
#   ['m72', datetime.date(2012, 2, 6), 2.0],
#   ['v06', datetime.date(2013, 2, 7), 2.0],
#   ['v11', datetime.date(2014, 3, 19), 2.0]],
#  '014_S_0169': [['bl', datetime.date(2006, 2, 16), 2.0],
#   ['m06', datetime.date(2006, 8, 24), 2.0],
#   ['m12', datetime.date(2007, 2, 27), 2.0],
#   ['m18', datetime.date(2007, 9, 11), 2.0],
#   ['m24', datetime.date(2008, 3, 4), 2.0],
#   ['m36', datetime.date(2009, 2, 24), 2.0],
#   ['m48', datetime.date(2010, 2, 4), 2.0],
#   ['m60', datetime.date(2011, 3, 8), 2.0],
#   ['v06', datetime.date(2012, 2, 16), 2.0],
#   ['v11', datetime.date(2013, 2, 28), 2.0],
#   ['v21', datetime.date(2014, 3, 24), 2.0],
#   ['v31', datetime.date(2015, 3, 3), 2.0]],
#  '010_S_0161': [['bl', datetime.date(2006, 2, 16), 2.0],
#   ['m06', datetime.date(2006, 8, 16), 2.0],
#   ['m12', datetime.date(2007, 3, 30), 3.0],
#   ['m18', datetime.date(2007, 8, 28), 3.0],
#   ['m24', datetime.date(2008, 2, 29), 3.0],
#   ['m36', datetime.date(2009, 3, 10), 3.0],
#   ['m48', datetime.date(2010, 4, 6), 3.0],
#   ['v06', datetime.date(2011, 7, 29), 3.0],
#   ['v11', datetime.date(2012, 7, 31), 3.0],
#   ['v21', datetime.date(2013, 9, 25), 3.0]],
#  '018_S_0142': [['bl', datetime.date(2006, 2, 20), 2.0],
#   ['m06', datetime.date(2006, 8, 24), 2.0],
#   ['m12', datetime.date(2007, 2, 19), 2.0],
#   ['m18', datetime.date(2007, 8, 9), 2.0],
#   ['m24', datetime.date(2008, 3, 11), 2.0],
#   ['m36', datetime.date(2009, 2, 27), 2.0],
#   ['m48', datetime.date(2010, 2, 26), 2.0],
#   ['m60', datetime.date(2010, 12, 20), 2.0],
#   ['v06', datetime.date(2012, 3, 23), 2.0],
#   ['v11', datetime.date(2013, 3, 25), 2.0],
#   ['v21', datetime.date(2014, 2, 27), 2.0],
#   ['v31', datetime.date(2015, 2, 4), 2.0],
#   ['v41', datetime.date(2016, 3, 9), 3.0]],
#  '123_S_0088': [['bl', datetime.date(2006, 2, 13), 3.0],
#   ['m06', datetime.date(2006, 8, 14), 3.0],
#   ['m12', datetime.date(2007, 2, 12), 3.0],
#   ['m24', datetime.date(2008, 3, 19), 3.0]],
#  '123_S_0108': [['bl', datetime.date(2006, 2, 14), 2.0],
#   ['m06', datetime.date(2006, 8, 8), 2.0],
#   ['m12', datetime.date(2007, 2, 22), 2.0],
#   ['m18', datetime.date(2007, 8, 9), 3.0],
#   ['m24', datetime.date(2008, 2, 26), 3.0],
#   ['m36', datetime.date(2009, 3, 10), 3.0],
#   ['m48', datetime.date(2010, 2, 25), 3.0],
#   ['m60', datetime.date(2011, 2, 15), 3.0],
#   ['v06', datetime.date(2011, 2, 15), 3.0]],
#  '027_S_0120': [['bl', datetime.date(2006, 2, 16), 1.0],
#   ['m06', datetime.date(2006, 8, 2), 1.0],
#   ['m12', datetime.date(2007, 2, 16), 1.0],
#   ['m24', datetime.date(2008, 2, 6), 1.0],
#   ['m36', datetime.date(2009, 2, 23), 1.0],
#   ['m48', datetime.date(2010, 2, 24), 1.0],
#   ['m60', datetime.date(2011, 2, 7), 1.0],
#   ['m72', datetime.date(2012, 3, 16), 1.0],
#   ['v06', datetime.date(2013, 2, 22), 1.0],
#   ['v11', datetime.date(2014, 2, 24), 1.0],
#   ['v21', datetime.date(2015, 2, 24), 1.0],
#   ['init', datetime.date(2017, 3, 29), 1.0]],
#  '128_S_0135': [['bl', datetime.date(2006, 2, 17), 2.0],
#   ['m06', datetime.date(2006, 8, 17), 2.0],
#   ['m12', datetime.date(2007, 2, 23), 2.0],
#   ['m18', datetime.date(2007, 8, 27), 2.0],
#   ['m24', datetime.date(2008, 2, 29), 2.0],
#   ['m36', datetime.date(2009, 3, 5), 2.0],
#   ['m48', datetime.date(2010, 9, 7), 3.0],
#   ['v06', datetime.date(2012, 2, 14), 2.0],
#   ['v11', datetime.date(2013, 2, 27), 3.0]],
#  '128_S_0138': [['bl', datetime.date(2006, 2, 21), 2.0],
#   ['m06', datetime.date(2006, 8, 16), 2.0],
#   ['m12', datetime.date(2007, 2, 21), 2.0],
#   ['m24', datetime.date(2008, 3, 4), 1.0],
#   ['m36', datetime.date(2011, 4, 21), 1.0],
#   ['v06', datetime.date(2012, 1, 4), 1.0],
#   ['v11', datetime.date(2013, 1, 4), 1.0],
#   ['v21', datetime.date(2012, 12, 6), 1.0],
#   ['v41', datetime.date(2016, 3, 1), 2.0]],
#  '032_S_0147': [['bl', datetime.date(2006, 2, 22), 3.0],
#   ['m06', datetime.date(2006, 9, 18), 3.0],
#   ['m12', datetime.date(2007, 2, 5), 3.0],
#   ['m24', datetime.date(2008, 4, 9), 3.0]],
#  '098_S_0171': [['bl', datetime.date(2006, 2, 21), 1.0],
#   ['m06', datetime.date(2006, 8, 1), 1.0],
#   ['m12', datetime.date(2007, 3, 6), 1.0],
#   ['m24', datetime.date(2008, 2, 21), 1.0],
#   ['m36', datetime.date(2009, 2, 23), 1.0],
#   ['m48', datetime.date(2010, 3, 8), 1.0],
#   ['v06', datetime.date(2011, 4, 27), 1.0],
#   ['v11', datetime.date(2012, 5, 9), 1.0],
#   ['v21', datetime.date(2013, 4, 10), 2.0]],
#  '041_S_0125': [['bl', datetime.date(2006, 2, 27), 1.0],
#   ['m06', datetime.date(2006, 8, 7), 1.0],
#   ['m12', datetime.date(2007, 1, 26), 1.0],
#   ['m24', datetime.date(2008, 2, 1), 1.0],
#   ['m36', datetime.date(2009, 2, 9), 1.0],
#   ['m48', datetime.date(2010, 3, 2), 1.0],
#   ['v06', datetime.date(2011, 6, 27), 1.0],
#   ['v11', datetime.date(2012, 10, 17), 1.0],
#   ['v21', datetime.date(2013, 7, 5), 1.0],
#   ['v41', datetime.date(2015, 1, 30), 1.0]],
#  '023_S_0217': [['bl', datetime.date(2006, 2, 28), 2.0],
#   ['m06', datetime.date(2006, 8, 15), 2.0],
#   ['m12', datetime.date(2007, 3, 2), 2.0],
#   ['m18', datetime.date(2007, 8, 9), 2.0],
#   ['m24', datetime.date(2008, 2, 25), 3.0],
#   ['m36', datetime.date(2009, 3, 6), 3.0],
#   ['m48', datetime.date(2010, 3, 12), 3.0],
#   ['m60', datetime.date(2011, 3, 4), 3.0],
#   ['v06', datetime.date(2012, 6, 12), 3.0]],
#  '114_S_0166': [['bl', datetime.date(2006, 2, 28), 1.0],
#   ['m06', datetime.date(2006, 8, 23), 1.0],
#   ['m12', datetime.date(2007, 2, 28), 1.0],
#   ['m24', datetime.date(2008, 2, 11), 1.0],
#   ['m36', datetime.date(2009, 3, 6), 1.0],
#   ['m60', datetime.date(2011, 6, 30), 3.0],
#   ['v06', datetime.date(2012, 2, 29), 2.0],
#   ['v11', datetime.date(2013, 2, 21), 3.0],
#   ['v21', datetime.date(2014, 4, 2), 3.0],
#   ['v31', datetime.date(2015, 7, 29), 3.0],
#   ['v41', datetime.date(2016, 3, 8), 3.0]],
#  '114_S_0173': [['bl', datetime.date(2006, 2, 28), 1.0],
#   ['m06', datetime.date(2006, 8, 28), 1.0],
#   ['m12', datetime.date(2007, 2, 22), 1.0],
#   ['m24', datetime.date(2008, 2, 12), 1.0],
#   ['m36', datetime.date(2009, 3, 2), 1.0],
#   ['v06', datetime.date(2012, 5, 3), 1.0],
#   ['v11', datetime.date(2013, 2, 21), 1.0],
#   ['v21', datetime.date(2014, 5, 28), 2.0],
#   ['v41', datetime.date(2016, 3, 10), 2.0]],
#  '136_S_0107': [['bl', datetime.date(2006, 2, 27), 2.0],
#   ['m06', datetime.date(2006, 8, 28), 2.0],
#   ['m12', datetime.date(2007, 2, 26), 2.0],
#   ['m18', datetime.date(2007, 9, 11), 2.0],
#   ['m24', datetime.date(2008, 2, 26), 2.0],
#   ['m36', datetime.date(2009, 6, 8), 2.0],
#   ['m48', datetime.date(2010, 6, 30), 2.0],
#   ['v06', datetime.date(2011, 6, 8), 2.0],
#   ['v11', datetime.date(2012, 9, 6), 2.0]],
#  '035_S_0204': [['bl', datetime.date(2006, 2, 23), 2.0],
#   ['m06', datetime.date(2006, 9, 19), 2.0],
#   ['m12', datetime.date(2007, 2, 27), 3.0],
#   ['m18', datetime.date(2007, 8, 30), 3.0],
#   ['m24', datetime.date(2008, 3, 21), 3.0],
#   ['m36', datetime.date(2009, 3, 6), 3.0],
#   ['m48', datetime.date(2010, 2, 5), 3.0]],
#  '035_S_0156': [['bl', datetime.date(2006, 2, 16), 1.0],
#   ['m06', datetime.date(2006, 9, 7), 1.0],
#   ['m12', datetime.date(2007, 2, 27), 1.0],
#   ['m24', datetime.date(2008, 2, 8), 1.0],
#   ['m36', datetime.date(2009, 6, 26), 1.0],
#   ['m48', datetime.date(2010, 2, 22), 1.0],
#   ['m60', datetime.date(2011, 5, 18), 1.0],
#   ['v06', datetime.date(2012, 6, 18), 1.0],
#   ['v11', datetime.date(2013, 2, 27), 2.0],
#   ['v21', datetime.date(2014, 3, 10), 2.0],
#   ['v31', datetime.date(2016, 8, 17), 2.0],
#   ['v41', datetime.date(2016, 8, 17), 2.0],
#   ['init', datetime.date(2017, 11, 8), 2.0],
#   ['y1', datetime.date(2018, 10, 15), 2.0],
#   ['y2', datetime.date(2019, 11, 4), 2.0]],
#  '021_S_0141': [['bl', datetime.date(2006, 3, 1), 2.0],
#   ['m06', datetime.date(2006, 8, 9), 2.0],
#   ['m12', datetime.date(2007, 3, 6), 3.0],
#   ['m18', datetime.date(2007, 8, 8), 3.0],
#   ['m24', datetime.date(2008, 3, 7), 3.0],
#   ['m36', datetime.date(2009, 3, 16), 3.0],
#   ['m48', datetime.date(2010, 2, 25), 3.0]],
#  '073_S_0089': [['bl', datetime.date(2006, 1, 31), 1.0],
#   ['m06', datetime.date(2006, 9, 28), 1.0],
#   ['m12', datetime.date(2007, 4, 24), 1.0],
#   ['m24', datetime.date(2008, 2, 6), 1.0],
#   ['m36', datetime.date(2009, 3, 11), 1.0],
#   ['m48', datetime.date(2010, 10, 28), 1.0],
#   ['v06', datetime.date(2011, 10, 26), 1.0],
#   ['v11', datetime.date(2013, 4, 12), 1.0],
#   ['v21', datetime.date(2013, 11, 22), 1.0],
#   ['v31', datetime.date(2015, 2, 18), 1.0],
#   ['init', datetime.date(2019, 2, 26), 1.0],
#   ['y2', datetime.date(2021, 8, 21), 1.0],
#   ['4_init', datetime.date(2023, 12, 15), 1.0]],
#  '068_S_0210': [['bl', datetime.date(2006, 3, 2), 1.0],
#   ['m06', datetime.date(2006, 11, 15), 1.0],
#   ['m36', datetime.date(2010, 2, 9), 2.0],
#   ['m12', datetime.date(2007, 7, 6), 1.0],
#   ['m24', datetime.date(2008, 7, 31), 1.0],
#   ['m48', datetime.date(2010, 5, 27), 2.0],
#   ['v06', datetime.date(2013, 6, 26), 2.0],
#   ['v31', datetime.date(2015, 9, 11), 2.0],
#   ['v41', datetime.date(2016, 11, 4), 1.0],
#   ['init', datetime.date(2017, 12, 7), 2.0]],
#  '068_S_0127': [['bl', datetime.date(2006, 3, 2), 1.0],
#   ['m06', datetime.date(2006, 9, 11), 1.0],
#   ['m12', datetime.date(2007, 4, 11), 1.0],
#   ['m24', datetime.date(2008, 6, 5), 1.0],
#   ['m36', datetime.date(2010, 2, 9), 1.0],
#   ['m48', datetime.date(2010, 5, 27), 1.0],
#   ['v06', datetime.date(2011, 7, 15), 2.0],
#   ['v11', datetime.date(2012, 3, 21), 2.0],
#   ['v21', datetime.date(2013, 6, 26), 2.0],
#   ['v31', datetime.date(2014, 4, 4), 2.0],
#   ['v41', datetime.date(2015, 5, 15), 2.0],
#   ['v51', datetime.date(2016, 4, 24), 2.0],
#   ['init', datetime.date(2017, 9, 26), 2.0],
#   ['y1', datetime.date(2018, 11, 8), 2.0],
#   ['y2', datetime.date(2020, 2, 25), 2.0],
#   ['y3', datetime.date(2020, 12, 11), 2.0],
#   ['y4', datetime.date(2024, 8, 26), 2.0]],
#  '032_S_0187': [['bl', datetime.date(2006, 3, 2), 2.0],
#   ['m06', datetime.date(2006, 9, 18), 2.0],
#   ['m12', datetime.date(2007, 3, 7), 2.0],
#   ['m18', datetime.date(2007, 8, 29), 2.0],
#   ['m24', datetime.date(2008, 3, 3), 3.0]],
#  '021_S_0159': [['bl', datetime.date(2006, 3, 3), 1.0],
#   ['m06', datetime.date(2006, 10, 4), 1.0],
#   ['m12', datetime.date(2007, 3, 12), 1.0],
#   ['m24', datetime.date(2008, 3, 5), 1.0],
#   ['m36', datetime.date(2009, 3, 19), 1.0],
#   ['m48', datetime.date(2010, 3, 16), 1.0],
#   ['m60', datetime.date(2011, 4, 28), 1.0],
#   ['v06', datetime.date(2012, 3, 8), 1.0],
#   ['v11', datetime.date(2013, 2, 27), 1.0],
#   ['v21', datetime.date(2014, 3, 24), 1.0],
#   ['v31', datetime.date(2015, 3, 5), 1.0],
#   ['init', datetime.date(2017, 5, 9), 1.0],
#   ['y2', datetime.date(2019, 5, 9), 1.0],
#   ['y4', datetime.date(2021, 4, 27), 1.0]],
#  '114_S_0228': [['bl', datetime.date(2006, 3, 3), 3.0],
#   ['m06', datetime.date(2006, 8, 25), 3.0]],
#  '067_S_0110': [['bl', datetime.date(2006, 3, 6), 3.0],
#   ['m06', datetime.date(2006, 10, 3), 3.0],
#   ['m12', datetime.date(2007, 3, 28), 3.0],
#   ['m24', datetime.date(2009, 1, 20), 3.0]],
#  '136_S_0186': [['bl', datetime.date(2006, 3, 6), 1.0],
#   ['m06', datetime.date(2006, 9, 18), 1.0],
#   ['m12', datetime.date(2007, 3, 5), 1.0],
#   ['m24', datetime.date(2008, 3, 3), 1.0],
#   ['m36', datetime.date(2009, 4, 28), 1.0],
#   ['m48', datetime.date(2010, 5, 25), 1.0],
#   ['v06', datetime.date(2011, 5, 23), 1.0],
#   ['v11', datetime.date(2012, 10, 11), 1.0],
#   ['v31', datetime.date(2014, 3, 20), 1.0]],
#  '027_S_0118': [['bl', datetime.date(2006, 2, 10), 1.0],
#   ['m06', datetime.date(2006, 8, 14), 1.0],
#   ['m12', datetime.date(2007, 2, 8), 1.0],
#   ['m24', datetime.date(2008, 2, 4), 1.0],
#   ['m36', datetime.date(2009, 2, 9), 1.0],
#   ['m48', datetime.date(2010, 2, 15), 1.0],
#   ['m60', datetime.date(2011, 2, 11), 1.0],
#   ['m72', datetime.date(2012, 2, 13), 1.0]],
#  '021_S_0178': [['bl', datetime.date(2006, 3, 9), 2.0],
#   ['m06', datetime.date(2006, 10, 5), 2.0],
#   ['m12', datetime.date(2007, 3, 14), 2.0],
#   ['m18', datetime.date(2007, 9, 10), 2.0],
#   ['m24', datetime.date(2008, 3, 24), 2.0],
#   ['m36', datetime.date(2009, 3, 18), 2.0],
#   ['m48', datetime.date(2010, 3, 18), 2.0],
#   ['m60', datetime.date(2011, 6, 3), 2.0],
#   ['v06', datetime.date(2012, 3, 8), 2.0],
#   ['v11', datetime.date(2013, 3, 14), 2.0],
#   ['v21', datetime.date(2014, 3, 7), 2.0],
#   ['v31', datetime.date(2015, 3, 19), 2.0],
#   ['v41', datetime.date(2016, 2, 29), 1.0],
#   ['init', datetime.date(2017, 4, 20), 1.0],
#   ['y2', datetime.date(2019, 6, 10), 1.0],
#   ['y4', datetime.date(2021, 4, 20), 1.0]],
#  '128_S_0205': [['bl', datetime.date(2006, 2, 28), 2.0],
#   ['m06', datetime.date(2006, 8, 16), 1.0],
#   ['m12', datetime.date(2007, 2, 22), 1.0],
#   ['m18', datetime.date(2007, 9, 28), 1.0],
#   ['m24', datetime.date(2008, 3, 6), 1.0],
#   ['m36', datetime.date(2009, 10, 16), 1.0],
#   ['v06', datetime.date(2012, 1, 4), 1.0],
#   ['v11', datetime.date(2013, 1, 4), 1.0],
#   ['v21', datetime.date(2013, 12, 19), 1.0],
#   ['v31', datetime.date(2015, 2, 6), 1.0],
#   ['v41', datetime.date(2016, 3, 8), 1.0],
#   ['init', datetime.date(2018, 7, 13), 1.0],
#   ['y2', datetime.date(2021, 5, 1), 1.0],
#   ['y4', datetime.date(2022, 7, 28), 1.0]],
#  '128_S_0188': [['bl', datetime.date(2006, 2, 22), 2.0],
#   ['m06', datetime.date(2006, 8, 9), 2.0],
#   ['m12', datetime.date(2007, 2, 8), 2.0],
#   ['m18', datetime.date(2007, 8, 8), 1.0],
#   ['m24', datetime.date(2008, 3, 4), 1.0],
#   ['m36', datetime.date(2009, 12, 10), 2.0]],
#  '128_S_0200': [['bl', datetime.date(2006, 3, 7), 2.0],
#   ['m06', datetime.date(2006, 9, 21), 2.0],
#   ['m12', datetime.date(2007, 3, 16), 2.0],
#   ['m18', datetime.date(2007, 8, 31), 2.0],
#   ['m24', datetime.date(2008, 3, 20), 2.0],
#   ['m36', datetime.date(2009, 10, 2), 2.0],
#   ['m48', datetime.date(2010, 10, 4), 2.0],
#   ['v06', datetime.date(2012, 2, 23), 2.0],
#   ['v11', datetime.date(2013, 3, 20), 2.0],
#   ['v21', datetime.date(2014, 4, 4), 2.0],
#   ['v31', datetime.date(2015, 5, 13), 2.0],
#   ['v41', datetime.date(2016, 3, 23), 2.0],
#   ['init', datetime.date(2018, 12, 6), 2.0]],
#  '128_S_0225': [['bl', datetime.date(2006, 3, 8), 2.0],
#   ['m06', datetime.date(2006, 9, 18), 2.0],
#   ['m12', datetime.date(2007, 3, 5), 2.0],
#   ['m18', datetime.date(2007, 8, 30), 2.0],
#   ['m24', datetime.date(2008, 3, 17), 2.0],
#   ['m36', datetime.date(2011, 4, 21), 2.0],
#   ['m48', datetime.date(2010, 10, 1), 2.0],
#   ['v06', datetime.date(2012, 2, 21), 2.0],
#   ['v11', datetime.date(2013, 3, 6), 2.0],
#   ['v21', datetime.date(2014, 3, 27), 2.0],
#   ['v31', datetime.date(2015, 3, 13), 2.0],
#   ['v41', datetime.date(2016, 4, 6), 2.0]],
#  '123_S_0162': [['bl', datetime.date(2006, 3, 9), 3.0],
#   ['m06', datetime.date(2006, 9, 21), 2.0],
#   ['m12', datetime.date(2007, 5, 2), 2.0],
#   ['m24', datetime.date(2008, 3, 14), 3.0]],
#  '032_S_0214': [['bl', datetime.date(2006, 3, 10), 2.0],
#   ['m06', datetime.date(2006, 9, 18), 2.0],
#   ['m12', datetime.date(2007, 3, 28), 2.0],
#   ['m18', datetime.date(2007, 9, 19), 2.0],
#   ['m24', datetime.date(2008, 3, 26), 3.0],
#   ['m36', datetime.date(2009, 3, 4), 3.0],
#   ['m48', datetime.date(2010, 7, 28), 3.0],
#   ['m60', datetime.date(2011, 5, 11), 3.0],
#   ['v06', datetime.date(2012, 5, 30), 3.0],
#   ['v11', datetime.date(2013, 10, 16), 3.0],
#   ['v21', datetime.date(2014, 5, 21), 3.0],
#   ['v41', datetime.date(2016, 4, 28), 3.0]],
#  '007_S_0249': [['bl', datetime.date(2006, 3, 14), 2.0],
#   ['m06', datetime.date(2006, 9, 27), 2.0],
#   ['m12', datetime.date(2007, 4, 9), 3.0],
#   ['m18', datetime.date(2007, 10, 17), 3.0],
#   ['m24', datetime.date(2008, 3, 31), 3.0],
#   ['m36', datetime.date(2009, 3, 12), 3.0],
#   ['m48', datetime.date(2010, 4, 29), 3.0]],
#  '020_S_0097': [['bl', datetime.date(2006, 3, 16), 1.0],
#   ['m06', datetime.date(2006, 9, 19), 1.0],
#   ['m12', datetime.date(2007, 3, 23), 1.0],
#   ['m24', datetime.date(2008, 4, 8), 1.0],
#   ['m36', datetime.date(2009, 4, 14), 1.0]],
#  '027_S_0179': [['bl', datetime.date(2006, 3, 10), 2.0],
#   ['m06', datetime.date(2006, 9, 14), 2.0],
#   ['m12', datetime.date(2007, 3, 15), 2.0],
#   ['m18', datetime.date(2007, 9, 10), 3.0],
#   ['m24', datetime.date(2008, 3, 6), 3.0],
#   ['m36', datetime.date(2009, 3, 10), 3.0]],
#  '128_S_0167': [['bl', datetime.date(2006, 3, 16), 3.0],
#   ['m06', datetime.date(2006, 9, 11), 2.0],
#   ['m12', datetime.date(2007, 5, 16), 2.0],
#   ['m24', datetime.date(2009, 2, 13), 2.0]],
#  '005_S_0222': [['bl', datetime.date(2006, 3, 17), 2.0],
#   ['m06', datetime.date(2006, 9, 15), 2.0],
#   ['m12', datetime.date(2007, 3, 28), 3.0],
#   ['m18', datetime.date(2007, 10, 1), 3.0],
#   ['m24', datetime.date(2008, 3, 12), 3.0]],
#  '137_S_0158': [['bl', datetime.date(2006, 3, 20), 2.0],
#   ['m06', datetime.date(2006, 10, 25), 2.0],
#   ['m12', datetime.date(2007, 3, 19), 2.0],
#   ['m18', datetime.date(2007, 9, 19), 2.0],
#   ['m24', datetime.date(2008, 4, 10), 2.0],
#   ['m36', datetime.date(2009, 4, 10), 2.0]],
#  '021_S_0231': [['bl', datetime.date(2006, 3, 23), 2.0],
#   ['m06', datetime.date(2006, 10, 6), 2.0],
#   ['m12', datetime.date(2007, 4, 4), 2.0],
#   ['m18', datetime.date(2007, 9, 24), 2.0],
#   ['m24', datetime.date(2008, 3, 21), 3.0],
#   ['m36', datetime.date(2008, 9, 4), 3.0]],
#  '123_S_0113': [['bl', datetime.date(2006, 3, 15), 1.0],
#   ['m06', datetime.date(2006, 9, 13), 1.0],
#   ['m12', datetime.date(2007, 3, 12), 1.0],
#   ['m24', datetime.date(2008, 3, 17), 1.0],
#   ['m36', datetime.date(2009, 3, 11), 1.0],
#   ['m48', datetime.date(2010, 4, 8), 1.0],
#   ['m60', datetime.date(2011, 3, 9), 1.0],
#   ['v06', datetime.date(2012, 3, 8), 1.0],
#   ['v11', datetime.date(2013, 3, 5), 1.0],
#   ['v21', datetime.date(2014, 3, 4), 1.0],
#   ['v31', datetime.date(2016, 5, 26), 1.0]],
#  '136_S_0184': [['bl', datetime.date(2006, 3, 27), 1.0],
#   ['m06', datetime.date(2006, 9, 5), 1.0],
#   ['m12', datetime.date(2007, 3, 20), 1.0],
#   ['m24', datetime.date(2008, 3, 18), 1.0],
#   ['m36', datetime.date(2009, 3, 18), 1.0]],
#  '018_S_0155': [['bl', datetime.date(2006, 3, 24), 2.0],
#   ['m06', datetime.date(2006, 9, 21), 2.0],
#   ['m12', datetime.date(2007, 3, 22), 2.0],
#   ['m18', datetime.date(2007, 9, 25), 2.0],
#   ['m24', datetime.date(2008, 3, 11), 2.0],
#   ['m36', datetime.date(2009, 3, 20), 3.0]],
#  '005_S_0223': [['bl', datetime.date(2006, 3, 24), 1.0],
#   ['m06', datetime.date(2006, 9, 15), 2.0],
#   ['m12', datetime.date(2007, 3, 28), 2.0],
#   ['m24', datetime.date(2008, 3, 21), 2.0],
#   ['m36', datetime.date(2009, 3, 20), 3.0]],
#  '005_S_0221': [['bl', datetime.date(2006, 3, 23), 3.0],
#   ['m06', datetime.date(2006, 9, 19), 3.0],
#   ['m12', datetime.date(2007, 3, 27), 3.0],
#   ['m24', datetime.date(2008, 4, 17), 3.0]],
#  '007_S_0293': [['bl', datetime.date(2006, 3, 28), 2.0],
#   ['m06', datetime.date(2006, 10, 31), 2.0],
#   ['m12', datetime.date(2007, 4, 18), 2.0],
#   ['m18', datetime.date(2007, 10, 23), 2.0],
#   ['m24', datetime.date(2008, 4, 21), 3.0],
#   ['m36', datetime.date(2009, 4, 7), 3.0]],
#  '067_S_0098': [['bl', datetime.date(2006, 3, 29), 2.0],
#   ['m06', datetime.date(2007, 1, 30), 2.0],
#   ['m12', datetime.date(2007, 5, 7), 2.0],
#   ['m24', datetime.date(2008, 6, 11), 2.0],
#   ['m36', datetime.date(2009, 4, 2), 3.0]],
#  '127_S_0259': [['bl', datetime.date(2006, 3, 28), 1.0],
#   ['m06', datetime.date(2006, 9, 29), 1.0],
#   ['m12', datetime.date(2007, 4, 5), 1.0],
#   ['m24', datetime.date(2008, 4, 4), 1.0],
#   ['m36', datetime.date(2009, 3, 31), 1.0],
#   ['m48', datetime.date(2010, 4, 14), 1.0],
#   ['m60', datetime.date(2011, 5, 23), 1.0],
#   ['v06', datetime.date(2012, 5, 17), 1.0],
#   ['v11', datetime.date(2013, 3, 29), 1.0],
#   ['v21', datetime.date(2014, 5, 9), 2.0],
#   ['v31', datetime.date(2015, 5, 1), 3.0],
#   ['v41', datetime.date(2016, 4, 21), 3.0],
#   ['init', datetime.date(2017, 11, 14), 3.0],
#   ['y1', datetime.date(2018, 11, 13), 3.0]],
#  '021_S_0276': [['bl', datetime.date(2006, 3, 31), 2.0],
#   ['m06', datetime.date(2006, 10, 4), 2.0],
#   ['m12', datetime.date(2007, 4, 9), 2.0],
#   ['m18', datetime.date(2007, 10, 4), 2.0],
#   ['m24', datetime.date(2008, 3, 13), 2.0],
#   ['m36', datetime.date(2009, 4, 8), 2.0],
#   ['m48', datetime.date(2010, 3, 31), 2.0],
#   ['m60', datetime.date(2011, 4, 25), 2.0],
#   ['v06', datetime.date(2012, 4, 5), 2.0],
#   ['v11', datetime.date(2013, 4, 16), 2.0],
#   ['v21', datetime.date(2014, 4, 3), 3.0],
#   ['v31', datetime.date(2015, 3, 24), 3.0],
#   ['v41', datetime.date(2016, 4, 4), 3.0]],
#  '098_S_0172': [['bl', datetime.date(2006, 3, 30), 1.0],
#   ['m06', datetime.date(2006, 10, 17), 1.0],
#   ['m12', datetime.date(2007, 4, 2), 1.0],
#   ['m24', datetime.date(2008, 4, 7), 1.0],
#   ['m36', datetime.date(2009, 3, 23), 1.0],
#   ['m48', datetime.date(2010, 4, 6), 1.0],
#   ['v06', datetime.date(2011, 3, 14), 1.0],
#   ['v11', datetime.date(2012, 4, 4), 1.0]],
#  '128_S_0229': [['bl', datetime.date(2006, 3, 30), 1.0],
#   ['m06', datetime.date(2006, 10, 18), 1.0],
#   ['m12', datetime.date(2007, 3, 23), 1.0],
#   ['m24', datetime.date(2008, 4, 4), 1.0],
#   ['m36', datetime.date(2009, 9, 16), 1.0],
#   ['m48', datetime.date(2010, 10, 7), 1.0],
#   ['v06', datetime.date(2012, 3, 14), 1.0],
#   ['v11', datetime.date(2013, 3, 20), 1.0],
#   ['v21', datetime.date(2014, 4, 17), 1.0],
#   ['v41', datetime.date(2016, 4, 20), 2.0]],
#  '136_S_0195': [['bl', datetime.date(2006, 4, 4), 2.0],
#   ['m06', datetime.date(2006, 10, 4), 2.0],
#   ['m12', datetime.date(2007, 3, 26), 3.0],
#   ['m18', datetime.date(2007, 9, 24), 3.0],
#   ['m24', datetime.date(2008, 3, 25), 3.0],
#   ['m36', datetime.date(2009, 4, 20), 3.0]],
#  '022_S_0219': [['bl', datetime.date(2006, 4, 4), 3.0],
#   ['m06', datetime.date(2006, 10, 17), 3.0]],
#  '037_S_0150': [['bl', datetime.date(2006, 3, 10), 2.0],
#   ['m06', datetime.date(2006, 10, 16), 2.0],
#   ['m12', datetime.date(2007, 4, 16), 2.0],
#   ['m18', datetime.date(2007, 9, 17), 2.0],
#   ['m24', datetime.date(2008, 2, 29), 2.0],
#   ['m36', datetime.date(2009, 5, 1), 2.0],
#   ['v06', datetime.date(2011, 9, 3), 2.0],
#   ['v11', datetime.date(2012, 8, 26), 2.0],
#   ['v31', datetime.date(2014, 6, 6), 2.0],
#   ['v41', datetime.date(2015, 3, 18), 2.0],
#   ['v51', datetime.date(2016, 3, 20), 2.0],
#   ['init', datetime.date(2017, 12, 13), 3.0]],
#  '027_S_0256': [['bl', datetime.date(2006, 4, 5), 2.0],
#   ['m06', datetime.date(2006, 10, 4), 3.0],
#   ['m12', datetime.date(2007, 4, 3), 3.0],
#   ['m18', datetime.date(2007, 10, 9), 3.0],
#   ['m24', datetime.date(2008, 4, 7), 3.0],
#   ['m36', datetime.date(2009, 4, 1), 3.0],
#   ['m48', datetime.date(2010, 4, 21), 3.0],
#   ['m60', datetime.date(2011, 4, 25), 3.0],
#   ['m72', datetime.date(2012, 3, 19), 3.0],
#   ['v06', datetime.date(2013, 6, 21), 3.0]],
#  '082_S_0304': [['bl', datetime.date(2006, 4, 6), 1.0],
#   ['m12', datetime.date(2007, 2, 15), 1.0],
#   ['m24', datetime.date(2008, 4, 17), 1.0],
#   ['m36', datetime.date(2009, 5, 5), 1.0]],
#  '128_S_0216': [['bl', datetime.date(2006, 2, 27), 3.0],
#   ['m06', datetime.date(2006, 9, 6), 3.0],
#   ['m12', datetime.date(2007, 2, 28), 3.0],
#   ['m24', datetime.date(2008, 3, 10), 3.0]],
#  '021_S_0273': [['bl', datetime.date(2006, 4, 11), 2.0],
#   ['m06', datetime.date(2006, 10, 16), 2.0],
#   ['m12', datetime.date(2007, 5, 22), 2.0],
#   ['m18', datetime.date(2007, 10, 10), 2.0],
#   ['m24', datetime.date(2008, 4, 7), 2.0],
#   ['m36', datetime.date(2009, 4, 8), 2.0]],
#  '128_S_0230': [['bl', datetime.date(2006, 3, 30), 1.0],
#   ['m06', datetime.date(2006, 10, 18), 1.0],
#   ['m12', datetime.date(2007, 3, 23), 1.0],
#   ['m24', datetime.date(2008, 4, 4), 1.0],
#   ['m36', datetime.date(2009, 9, 16), 3.0],
#   ['v06', datetime.date(2012, 1, 12), 3.0],
#   ['v11', datetime.date(2013, 1, 31), 3.0],
#   ['v21', datetime.date(2014, 2, 12), 3.0],
#   ['v31', datetime.date(2015, 2, 6), 3.0]],
#  '023_S_0331': [['bl', datetime.date(2006, 4, 6), 2.0],
#   ['m06', datetime.date(2006, 10, 3), 2.0],
#   ['m12', datetime.date(2007, 3, 30), 2.0],
#   ['m18', datetime.date(2007, 10, 11), 2.0],
#   ['m24', datetime.date(2008, 4, 1), 2.0],
#   ['m36', datetime.date(2009, 4, 13), 3.0],
#   ['m48', datetime.date(2010, 5, 6), 3.0],
#   ['v06', datetime.date(2011, 5, 13), 3.0],
#   ['v11', datetime.date(2012, 6, 12), 3.0],
# ...
#   ['v06', datetime.date(2012, 6, 5), 2.0],
#   ['v11', datetime.date(2013, 6, 13), 3.0],
#   ['v21', datetime.date(2014, 5, 23), 3.0],
#   ['v31', datetime.date(2015, 6, 11), 3.0]],
#  '036_S_2380': [['bl', datetime.date(2011, 8, 11), 2.0],
#   ['m06', datetime.date(2012, 2, 13), 2.0],
#   ['v06', datetime.date(2012, 7, 31), 2.0],
#   ['v11', datetime.date(2013, 8, 13), 2.0],
#   ['v21', datetime.date(2014, 10, 2), 2.0],
#   ['v31', datetime.date(2015, 8, 19), 2.0],
#   ['v41', datetime.date(2016, 11, 9), 2.0],
#   ['v51', datetime.date(2017, 5, 5), 2.0],
#   ['init', datetime.date(2018, 6, 19), 2.0],
#   ['y1', datetime.date(2019, 6, 6), 2.0],
#   ['y2', datetime.date(2021, 1, 13), 3.0]],
#  '029_S_2376': [['bl', datetime.date(2011, 7, 19), 2.0],
#   ['m06', datetime.date(2011, 12, 7), 2.0],
#   ['v06', datetime.date(2012, 7, 19), 2.0],
#   ['v11', datetime.date(2013, 7, 25), 2.0],
#   ['v31', datetime.date(2015, 11, 19), 2.0]],
#  '029_S_2395': [['bl', datetime.date(2011, 9, 1), 2.0],
#   ['m06', datetime.date(2012, 2, 28), 2.0],
#   ['v06', datetime.date(2012, 8, 22), 2.0],
#   ['v11', datetime.date(2013, 8, 15), 2.0],
#   ['v41', datetime.date(2016, 4, 21), 2.0],
#   ['init', datetime.date(2018, 4, 19), 2.0],
#   ['y1', datetime.date(2019, 4, 18), 2.0],
#   ['y2', datetime.date(2020, 3, 2), 2.0]],
#  '053_S_2396': [['bl', datetime.date(2011, 8, 30), 2.0],
#   ['m06', datetime.date(2012, 2, 17), 2.0],
#   ['v06', datetime.date(2012, 7, 27), 2.0],
#   ['v11', datetime.date(2013, 7, 26), 2.0],
#   ['v21', datetime.date(2014, 8, 8), 2.0],
#   ['v41', datetime.date(2016, 9, 9), 2.0]],
#  '007_S_2394': [['bl', datetime.date(2011, 9, 16), 2.0],
#   ['m06', datetime.date(2012, 2, 10), 2.0],
#   ['v06', datetime.date(2012, 7, 12), 2.0],
#   ['v11', datetime.date(2013, 8, 6), 2.0],
#   ['v21', datetime.date(2014, 8, 12), 2.0],
#   ['v31', datetime.date(2015, 7, 14), 2.0],
#   ['v41', datetime.date(2016, 8, 2), 2.0],
#   ['init', datetime.date(2017, 8, 15), 2.0],
#   ['y1', datetime.date(2018, 8, 16), 2.0],
#   ['y2', datetime.date(2019, 8, 1), 2.0],
#   ['y5', datetime.date(2022, 8, 24), 1.0],
#   ['4_init', datetime.date(2023, 10, 31), 1.0]],
#  '126_S_2405': [['bl', datetime.date(2011, 10, 11), 2.0],
#   ['m06', datetime.date(2012, 4, 25), 2.0],
#   ['v06', datetime.date(2012, 10, 9), 2.0],
#   ['v11', datetime.date(2013, 10, 29), 2.0],
#   ['v21', datetime.date(2014, 12, 9), 2.0],
#   ['v31', datetime.date(2015, 10, 20), 2.0],
#   ['v41', datetime.date(2016, 10, 3), 2.0],
#   ['v51', datetime.date(2017, 10, 16), 2.0]],
#  '114_S_2392': [['bl', datetime.date(2011, 7, 11), 2.0],
#   ['m06', datetime.date(2012, 2, 1), 2.0],
#   ['v06', datetime.date(2012, 9, 20), 2.0],
#   ['v11', datetime.date(2013, 9, 4), 2.0],
#   ['v21', datetime.date(2014, 11, 5), 2.0],
#   ['v31', datetime.date(2015, 7, 29), 2.0],
#   ['v41', datetime.date(2017, 3, 1), 2.0],
#   ['init', datetime.date(2017, 7, 25), 2.0],
#   ['y1', datetime.date(2018, 10, 18), 2.0],
#   ['y2', datetime.date(2019, 10, 16), 2.0],
#   ['y3', datetime.date(2021, 2, 4), 2.0],
#   ['y4', datetime.date(2021, 9, 27), 2.0],
#   ['y5', datetime.date(2022, 8, 29), 2.0]],
#  '126_S_2407': [['bl', datetime.date(2011, 12, 6), 2.0],
#   ['m06', datetime.date(2012, 5, 28), 2.0],
#   ['v06', datetime.date(2012, 12, 10), 2.0],
#   ['v11', datetime.date(2013, 11, 26), 2.0],
#   ['v21', datetime.date(2014, 12, 1), 2.0],
#   ['v31', datetime.date(2015, 12, 21), 2.0],
#   ['v41', datetime.date(2016, 11, 29), 2.0]],
#  '130_S_2403': [['bl', datetime.date(2012, 9, 15), 2.0],
#   ['m06', datetime.date(2012, 9, 15), 2.0],
#   ['v06', datetime.date(2012, 10, 19), 2.0],
#   ['v11', datetime.date(2013, 10, 18), 2.0],
#   ['v21', datetime.date(2014, 10, 17), 3.0],
#   ['init', datetime.date(2017, 10, 3), 3.0],
#   ['y2', datetime.date(2019, 8, 9), 3.0]],
#  '100_S_2351': [['bl', datetime.date(2011, 9, 8), 2.0]],
#  '072_S_4007': [['v01', datetime.date(2011, 3, 4), 2.0],
#   ['v03', datetime.date(2011, 5, 5), 2.0],
#   ['v05', datetime.date(2011, 11, 29), 2.0],
#   ['v11', datetime.date(2012, 3, 27), 2.0],
#   ['v21', datetime.date(2013, 4, 1), 2.0]],
#  '098_S_4003': [['v01', datetime.date(2011, 2, 22), 1.0],
#   ['v03', datetime.date(2011, 4, 15), 1.0],
#   ['v05', datetime.date(2011, 10, 7), 1.0],
#   ['v11', datetime.date(2012, 4, 19), 1.0],
#   ['v21', datetime.date(2013, 5, 8), 1.0],
#   ['v31', datetime.date(2014, 4, 15), 1.0],
#   ['v51', datetime.date(2016, 4, 19), 1.0],
#   ['init', datetime.date(2017, 12, 7), 1.0],
#   ['y2', datetime.date(2020, 3, 3), 1.0]],
#  '098_S_4002': [['v01', datetime.date(2011, 2, 14), 1.0]],
#  '116_S_4010': [['v01', datetime.date(2011, 3, 28), 1.0],
#   ['v03', datetime.date(2011, 4, 18), 1.0],
#   ['v05', datetime.date(2011, 10, 25), 1.0],
#   ['v11', datetime.date(2012, 5, 1), 1.0],
#   ['v21', datetime.date(2013, 4, 22), 1.0],
#   ['v31', datetime.date(2014, 4, 18), 1.0]],
#  '041_S_4014': [['v01', datetime.date(2011, 3, 28), 1.0],
#   ['v03', datetime.date(2011, 6, 16), 1.0],
#   ['v05', datetime.date(2012, 1, 24), 1.0],
#   ['v11', datetime.date(2012, 6, 8), 1.0],
#   ['v21', datetime.date(2013, 7, 5), 1.0],
#   ['v41', datetime.date(2015, 6, 11), 1.0]],
#  '116_S_4013': [['v01', datetime.date(2011, 3, 29), 2.0]],
#  '031_S_4005': [['v01', datetime.date(2011, 3, 21), 2.0],
#   ['v03', datetime.date(2011, 5, 11), 2.0],
#   ['v05', datetime.date(2011, 10, 26), 2.0],
#   ['v11', datetime.date(2012, 4, 30), 3.0],
#   ['v21', datetime.date(2013, 4, 29), 3.0],
#   ['v31', datetime.date(2015, 4, 10), 2.0],
#   ['v41', datetime.date(2017, 1, 30), 2.0]],
#  '041_S_4004': [['v01', datetime.date(2011, 3, 29), 2.0],
#   ['v03', datetime.date(2011, 6, 27), 2.0],
#   ['v05', datetime.date(2012, 1, 24), 2.0],
#   ['v11', datetime.date(2012, 5, 16), 2.0],
#   ['v21', datetime.date(2013, 7, 5), 2.0],
#   ['v31', datetime.date(2014, 6, 3), 2.0],
#   ['v41', datetime.date(2015, 7, 13), 2.0],
#   ['v51', datetime.date(2019, 2, 27), 1.0],
#   ['init', datetime.date(2018, 3, 8), 1.0]],
#  '037_S_4015': [['v01', datetime.date(2011, 3, 25), 2.0],
#   ['v03', datetime.date(2011, 5, 3), 2.0],
#   ['v05', datetime.date(2011, 12, 5), 2.0],
#   ['v11', datetime.date(2012, 4, 26), 2.0],
#   ['v21', datetime.date(2013, 5, 8), 3.0],
#   ['v31', datetime.date(2014, 6, 20), 3.0],
#   ['v41', datetime.date(2015, 4, 23), 3.0],
#   ['v51', datetime.date(2016, 4, 11), 3.0]],
#  '031_S_4006': [['v01', datetime.date(2011, 4, 4), 1.0]],
#  '012_S_4012': [['v01', datetime.date(2011, 3, 22), 2.0],
#   ['v03', datetime.date(2011, 5, 11), 2.0],
#   ['v05', datetime.date(2012, 2, 1), 2.0],
#   ['v11', datetime.date(2012, 6, 4), 2.0],
#   ['v21', datetime.date(2013, 5, 13), 2.0],
#   ['v31', datetime.date(2014, 6, 26), 2.0],
#   ['v41', datetime.date(2015, 5, 26), 2.0]],
#  '098_S_4018': [['v01', datetime.date(2011, 4, 5), 1.0],
#   ['v03', datetime.date(2011, 6, 2), 1.0],
#   ['v05', datetime.date(2011, 11, 28), 1.0],
#   ['v11', datetime.date(2012, 5, 21), 1.0],
#   ['v21', datetime.date(2013, 5, 6), 1.0],
#   ['v41', datetime.date(2015, 6, 10), 1.0]],
#  '098_S_4017': [['v01', datetime.date(2011, 4, 5), 1.0]],
#  '031_S_4021': [['v01', datetime.date(2011, 4, 11), 1.0],
#   ['v03', datetime.date(2011, 6, 13), 1.0],
#   ['v05', datetime.date(2011, 10, 26), 1.0],
#   ['v11', datetime.date(2012, 4, 26), 1.0],
#   ['v21', datetime.date(2013, 5, 17), 1.0],
#   ['v31', datetime.date(2015, 1, 16), 1.0],
#   ['init', datetime.date(2018, 11, 26), 1.0],
#   ['y1', datetime.date(2019, 11, 7), 1.0]],
#  '023_S_4020': [['v01', datetime.date(2011, 4, 12), 1.0],
#   ['v03', datetime.date(2011, 6, 28), 1.0],
#   ['v05', datetime.date(2012, 2, 3), 1.0],
#   ['v11', datetime.date(2012, 7, 18), 1.0],
#   ['v21', datetime.date(2013, 6, 12), 1.0],
#   ['v41', datetime.date(2015, 8, 10), 1.0]],
#  '031_S_4024': [['v01', datetime.date(2011, 4, 13), 3.0],
#   ['v03', datetime.date(2011, 5, 11), 3.0],
#   ['v05', datetime.date(2011, 11, 8), 3.0],
#   ['v11', datetime.date(2012, 4, 30), 3.0],
#   ['v21', datetime.date(2012, 12, 17), 3.0]],
#  '099_S_4022': [['v01', datetime.date(2011, 4, 15), 2.0],
#   ['v03', datetime.date(2011, 4, 29), 2.0],
#   ['v05', datetime.date(2011, 10, 24), 2.0],
#   ['v11', datetime.date(2012, 4, 26), 2.0]],
#  '037_S_4028': [['v01', datetime.date(2011, 4, 18), 1.0],
#   ['v03', datetime.date(2011, 6, 15), 1.0],
#   ['v05', datetime.date(2011, 12, 5), 1.0],
#   ['v11', datetime.date(2012, 5, 7), 1.0],
#   ['v21', datetime.date(2013, 6, 7), 1.0],
#   ['v41', datetime.date(2015, 7, 23), 1.0],
#   ['init', datetime.date(2017, 11, 17), 1.0],
#   ['y2', datetime.date(2019, 11, 21), 1.0],
#   ['y4', datetime.date(2021, 11, 30), 1.0],
#   ['4_init', datetime.date(2024, 8, 20), 1.0]],
#  '031_S_4029': [['v01', datetime.date(2011, 4, 18), 2.0],
#   ['v03', datetime.date(2011, 5, 19), 2.0],
#   ['v05', datetime.date(2011, 12, 5), 2.0],
#   ['v11', datetime.date(2012, 5, 25), 2.0],
#   ['v21', datetime.date(2013, 5, 17), 2.0],
#   ['v31', datetime.date(2015, 1, 16), 2.0]],
#  '031_S_4032': [['v01', datetime.date(2011, 4, 25), 1.0],
#   ['v03', datetime.date(2011, 6, 13), 1.0],
#   ['v05', datetime.date(2011, 12, 16), 1.0],
#   ['v11', datetime.date(2012, 5, 25), 1.0],
#   ['v21', datetime.date(2013, 5, 17), 1.0]],
#  '037_S_4030': [['v01', datetime.date(2011, 4, 25), 2.0],
#   ['v03', datetime.date(2011, 6, 15), 2.0],
#   ['v05', datetime.date(2011, 12, 5), 2.0],
#   ['v11', datetime.date(2012, 8, 10), 2.0],
#   ['v21', datetime.date(2013, 6, 7), 2.0],
#   ['v31', datetime.date(2014, 5, 25), 3.0],
#   ['v41', datetime.date(2015, 6, 11), 3.0],
#   ['v51', datetime.date(2016, 6, 20), 3.0],
#   ['init', datetime.date(2017, 10, 23), 3.0],
#   ['y1', datetime.date(2018, 10, 1), 3.0]],
#  '035_S_4033': [['v01', datetime.date(2011, 4, 27), 3.0]],
#  '037_S_4001': [['v01', datetime.date(2011, 5, 4), 3.0],
#   ['v03', datetime.date(2011, 3, 10), 3.0],
#   ['v05', datetime.date(2011, 10, 12), 3.0],
#   ['v11', datetime.date(2012, 3, 27), 3.0],
#   ['v21', datetime.date(2013, 3, 20), 3.0]],
#  '941_S_4036': [['v01', datetime.date(2011, 5, 6), 2.0],
#   ['v03', datetime.date(2011, 7, 11), 2.0],
#   ['v05', datetime.date(2012, 2, 2), 2.0],
#   ['v11', datetime.date(2012, 8, 31), 2.0],
#   ['v21', datetime.date(2014, 1, 14), 2.0],
#   ['v31', datetime.date(2014, 7, 18), 2.0],
#   ['v41', datetime.date(2015, 6, 26), 2.0],
#   ['v51', datetime.date(2016, 6, 27), 2.0],
#   ['init', datetime.date(2017, 11, 27), 2.0],
#   ['y1', datetime.date(2018, 11, 20), 2.0],
#   ['y2', datetime.date(2020, 2, 19), 2.0],
#   ['y3', datetime.date(2021, 3, 17), 2.0],
#   ['y4', datetime.date(2022, 3, 16), 2.0],
#   ['y5', datetime.date(2023, 4, 13), 2.0],
#   ['4_init', datetime.date(2024, 3, 27), 2.0]],
#  '941_S_4023': [['v01', datetime.date(2011, 5, 6), 1.0]],
#  '041_S_4037': [['v01', datetime.date(2011, 4, 29), 1.0],
#   ['v03', datetime.date(2011, 6, 27), 1.0],
#   ['v05', datetime.date(2012, 1, 24), 1.0],
#   ['v11', datetime.date(2012, 7, 25), 1.0],
#   ['v21', datetime.date(2013, 7, 5), 1.0],
#   ['v41', datetime.date(2015, 9, 16), 1.0],
#   ['init', datetime.date(2017, 7, 13), 1.0],
#   ['y2', datetime.date(2019, 5, 9), 1.0]],
#  '041_S_4041': [['v01', datetime.date(2011, 5, 6), 1.0],
#   ['v03', datetime.date(2011, 8, 30), 1.0],
#   ['v05', datetime.date(2012, 1, 25), 2.0],
#   ['v11', datetime.date(2012, 7, 13), 2.0],
#   ['v21', datetime.date(2013, 7, 8), 3.0],
#   ['v31', datetime.date(2014, 8, 6), 3.0],
#   ['v41', datetime.date(2015, 7, 13), 3.0],
#   ['init', datetime.date(2018, 4, 16), 3.0]],
#  '072_S_4008': [['v01', datetime.date(2011, 5, 10), 2.0]],
#  '099_S_4046': [['v01', datetime.date(2011, 5, 9), 2.0]],
#  '023_S_4034': [['v01', datetime.date(2011, 5, 5), 2.0],
#   ['v03', datetime.date(2011, 7, 31), 2.0],
#   ['v05', datetime.date(2011, 12, 13), 2.0],
#   ['v11', datetime.date(2012, 7, 30), 2.0]],
#  '116_S_4043': [['v01', datetime.date(2011, 5, 10), 1.0],
#   ['v03', datetime.date(2011, 6, 2), 1.0],
#   ['v05', datetime.date(2011, 12, 7), 1.0],
#   ['v11', datetime.date(2012, 5, 22), 1.0],
#   ['v21', datetime.date(2013, 7, 15), 1.0],
#   ['v41', datetime.date(2015, 5, 21), 1.0],
#   ['init', datetime.date(2018, 4, 11), 1.0],
#   ['y1', datetime.date(2019, 1, 28), 1.0],
#   ['y2', datetime.date(2020, 2, 18), 1.0],
#   ['y4', datetime.date(2022, 2, 16), 1.0]],
#  '012_S_4026': [['v01', datetime.date(2011, 5, 3), 1.0],
#   ['v03', datetime.date(2011, 8, 1), 1.0],
#   ['v05', datetime.date(2012, 1, 9), 1.0],
#   ['v11', datetime.date(2012, 7, 6), 1.0],
#   ['v21', datetime.date(2013, 6, 24), 1.0]],
#  '031_S_4042': [['v01', datetime.date(2011, 5, 11), 2.0],
#   ['v03', datetime.date(2011, 6, 13), 2.0],
#   ['v05', datetime.date(2011, 12, 21), 2.0],
#   ['v11', datetime.date(2012, 5, 25), 2.0],
#   ['v21', datetime.date(2013, 3, 7), 3.0]],
#  '072_S_4056': [['v01', datetime.date(2011, 5, 18), 1.0]],
#  '098_S_4050': [['v01', datetime.date(2011, 5, 10), 1.0],
#   ['v03', datetime.date(2011, 6, 21), 1.0],
#   ['v05', datetime.date(2011, 11, 29), 1.0],
#   ['v11', datetime.date(2012, 6, 22), 1.0],
#   ['v21', datetime.date(2013, 6, 25), 1.0],
#   ['v41', datetime.date(2015, 6, 30), 1.0]],
#  '098_S_4059': [['v01', datetime.date(2011, 5, 17), 2.0],
#   ['v03', datetime.date(2011, 6, 14), 2.0],
#   ['v05', datetime.date(2011, 12, 14), 2.0],
#   ['v11', datetime.date(2012, 8, 8), 2.0]],
#  '041_S_4060': [['v01', datetime.date(2011, 5, 18), 1.0],
#   ['v03', datetime.date(2011, 6, 27), 1.0],
#   ['v05', datetime.date(2012, 1, 24), 1.0],
#   ['v11', datetime.date(2012, 7, 13), 1.0],
#   ['v21', datetime.date(2013, 7, 5), 1.0],
#   ['v41', datetime.date(2015, 6, 5), 1.0],
#   ['init', datetime.date(2017, 9, 12), 1.0],
#   ['y2', datetime.date(2019, 9, 11), 1.0]],
#  '141_S_4053': [['v01', datetime.date(2011, 5, 16), 2.0],
#   ['v03', datetime.date(2011, 6, 23), 2.0],
#   ['v05', datetime.date(2012, 2, 17), 2.0],
#   ['v11', datetime.date(2012, 6, 22), 2.0]],
#  '067_S_4054': [['v01', datetime.date(2011, 5, 19), 2.0],
#   ['v03', datetime.date(2011, 6, 22), 2.0],
#   ['v05', datetime.date(2011, 12, 16), 2.0],
#   ['v11', datetime.date(2012, 6, 13), 1.0],
#   ['v21', datetime.date(2013, 6, 26), 1.0],
#   ['v31', datetime.date(2014, 6, 3), 1.0],
#   ['v41', datetime.date(2015, 7, 9), 1.0]],
#  '067_S_4055': [['v01', datetime.date(2011, 5, 19), 1.0]],
#  '072_S_4063': [['v01', datetime.date(2011, 5, 20), 2.0],
#   ['v03', datetime.date(2011, 7, 13), 2.0],
#   ['v05', datetime.date(2012, 1, 19), 2.0],
#   ['v11', datetime.date(2012, 9, 11), 2.0],
#   ['v21', datetime.date(2013, 8, 21), 2.0],
#   ['v31', datetime.date(2014, 7, 30), 2.0],
#   ['v41', datetime.date(2015, 7, 8), 2.0],
#   ['v51', datetime.date(2016, 2, 17), 2.0]],
#  '014_S_4058': [['v01', datetime.date(2011, 5, 19), 2.0],
#   ['v03', datetime.date(2011, 6, 16), 2.0],
#   ['v05', datetime.date(2012, 1, 6), 2.0],
#   ['v11', datetime.date(2012, 6, 22), 2.0],
#   ['v21', datetime.date(2013, 7, 18), 3.0]],
#  '014_S_4039': [['v01', datetime.date(2011, 4, 27), 3.0],
#   ['v03', datetime.date(2011, 7, 1), 3.0],
#   ['v05', datetime.date(2011, 12, 14), 3.0],
#   ['v11', datetime.date(2012, 6, 19), 3.0],
#   ['v21', datetime.date(2013, 6, 25), 3.0]],
#  '072_S_4057': [['v01', datetime.date(2011, 5, 18), 2.0],
#   ['v03', datetime.date(2011, 6, 13), 2.0],
#   ['v05', datetime.date(2012, 1, 23), 3.0],
#   ['v11', datetime.date(2012, 9, 11), 3.0],
#   ['v21', datetime.date(2013, 8, 6), 3.0]],
#  '014_S_4068': [['v01', datetime.date(2011, 5, 24), 2.0]],
#  '099_S_4065': [['v01', datetime.date(2011, 5, 25), 3.0]],
#  '068_S_4061': [['v01', datetime.date(2011, 5, 27), 2.0],
#   ['v03', datetime.date(2011, 7, 15), 2.0],
#   ['v05', datetime.date(2012, 1, 18), 2.0],
#   ['v11', datetime.date(2013, 8, 26), 2.0],
#   ['v21', datetime.date(2014, 4, 4), 2.0],
#   ['v31', datetime.date(2014, 10, 31), 1.0],
#   ['v41', datetime.date(2015, 9, 2), 2.0],
#   ['v51', datetime.date(2016, 11, 23), 2.0],
#   ['init', datetime.date(2017, 10, 25), 1.0],
#   ['y2', datetime.date(2019, 11, 27), 1.0]],
#  '068_S_4067': [['v01', datetime.date(2011, 5, 27), 2.0],
#   ['v03', datetime.date(2011, 7, 15), 2.0],
#   ['v11', datetime.date(2013, 10, 9), 2.0],
#   ['v31', datetime.date(2014, 10, 31), 2.0],
#   ['v41', datetime.date(2015, 9, 2), 2.0],
#   ['init', datetime.date(2017, 10, 25), 2.0]],
#  '116_S_4038': [['v01', datetime.date(2011, 6, 1), 3.0]],
#  '941_S_4016': [['v01', datetime.date(2011, 6, 2), 1.0]],
#  '941_S_4031': [['v01', datetime.date(2011, 6, 2), 2.0]],
#  '941_S_4044': [['v01', datetime.date(2011, 6, 2), 2.0]],
#  ...}

# %% [markdown]
# **Creating a dictionary of patients who only ever got CN diagnosis.**
#
# Iterates through every visit of every patient, adding the patient to the cn dictionary only if they exclusively have CN diagnoses in their records. The dictionary also contains all the visits, wich are all relevant for the dataset.

# %%
cn_dict = {}

for patient_id in patient_dict:
    always_cn = True
    visits = patient_dict[patient_id]

    for i in range(0, len(visits)):

        if visits[i][2] != 1.0:
            always_cn = False

    if always_cn and len(visits) >= 5:
        cn_dict[patient_id] = visits

np.save("data/cn_dict.npy", cn_dict)

# %%
print('Number of patients:', len(cn_dict))

num_relevant_visits = 0

for key in cn_dict:
   num_relevant_visits += len(cn_dict[key]) 
    
print('Number of relevant visits:', num_relevant_visits)
# Out:
# Number of patients: 356
# Number of relevant visits: 2561

# %% [markdown]
# **Creating a dictionary of patients who only ever got AD diagnosis.**
#
# Iterates through every visit of every patient, adding the patient to the cn dictionary only if they exclusively have AD diagnoses in their records. The dictionary also contains all the visits, wich are all relevant for the dataset.

# %%
ad_dict = {}

for patient_id in patient_dict:
    always_ad = True
    visits = patient_dict[patient_id]

    for i in range(0, len(visits)):

        if visits[i][2] != 3.0:
            always_ad = False

    if always_ad:
        ad_dict[patient_id] = visits

np.save("data/ad_dict.npy", ad_dict)

# %%
print('Number of patients:', len(ad_dict))

num_relevant_visits = 0

for key in ad_dict:
   num_relevant_visits += len(ad_dict[key]) 
    
print('Number of relevant visits:', num_relevant_visits) 

#ad_dict['011_S_0003']
# Out:
# Number of patients: 512
# Number of relevant visits: 1577

# %% [markdown]
# **Creating a dictionary for patients with sMCI diagnosis**
#
# Iterates through every visit of every patient, adding the patient to the sMCI dictionary if they have hava an unbroken streak of 5 visits with MCI diagnosis including the last recordedd visit. The dictionary only contains visits with MCI diagnosis.

# %%
smci_dict = {}

for patient_id in patient_dict:
    always_mci = True
    relevant_visits = list()
    mci_count = 0
    visits = patient_dict[patient_id]

    for i in range(0, len(visits)):

        if visits[i][2] == 1.0:
            mci_count = 0
            relevant_visits.clear()

        elif visits[i][2] == 2.0:
            relevant_visits.append(visits[i])
            mci_count += 1
        
        elif visits[i][2] == 3.0:
            always_mci = False
            relevant_visits.clear()

    if always_mci and mci_count >= 5:
        smci_dict[patient_id] = relevant_visits

np.save("data/smci_dict.npy", smci_dict)

# %%
print('Number of patients:', len(smci_dict))

num_relevant_visits = 0

for key in smci_dict:
   num_relevant_visits += len(smci_dict[key]) 
    
print('Number of relevant visits:', num_relevant_visits) 
smci_dict['022_S_0004']
# Out:
# Number of patients: 356
# Number of relevant visits: 2572
# [['bl', datetime.date(2005, 11, 8), 2.0],
#  ['m06', datetime.date(2006, 5, 2), 2.0],
#  ['m12', datetime.date(2006, 11, 14), 2.0],
#  ['m18', datetime.date(2007, 5, 14), 2.0],
#  ['m36', datetime.date(2008, 11, 18), 2.0]]

# %% [markdown]
# **Creating a dictionary for patients with pMCI diagnosis**
#
# Iterates through every visit of every patient, adding the patient to the pMCI dictionary if they convert to AD within 36 months of being diagnosed with MCI, without regressing back to CN. The dictionary only contains visits with MCI diagnosis.

# %%
pmci_dict = {}

for patient_id in patient_dict:
    ad_detected = False
    mci_count = 0
    relevant_visits = list()
    visits = patient_dict[patient_id]

    for i in range(0, len(visits)):

        if visits[i][2] == 1.0:
            mci_count = 0
            relevant_visits.clear()

        elif visits[i][2] == 2.0:
            mci_count += 1
            relevant_visits.append(visits[i])

        elif visits[i][2] == 3.0:
            ad_detected = True
            break

    if  ad_detected and (1 <= mci_count <= 6):
        pmci_dict[patient_id] = relevant_visits

np.save("data/pmci_dict.npy", pmci_dict)

# %%
print('Number of patients:', len(pmci_dict))

num_relevant_visits = 0

for key in pmci_dict:
   num_relevant_visits += len(pmci_dict[key]) 
    
print('Number of relevant visits:', num_relevant_visits)  
pmci_dict['099_S_0051']
# Out:
# Number of patients: 384
# Number of relevant visits: 1263
# [['bl', datetime.date(2005, 12, 29), 2.0],
#  ['m06', datetime.date(2006, 9, 1), 2.0],
#  ['m12', datetime.date(2007, 2, 1), 2.0],
#  ['m18', datetime.date(2007, 7, 9), 2.0],
#  ['m24', datetime.date(2007, 12, 13), 2.0],
#  ['m36', datetime.date(2008, 12, 12), 2.0]]

# %%
mci_dict = {}

for patient_id in patient_dict:
    ad_detected = False
    mci_count = 0
    relevant_visits = list()
    visits = patient_dict[patient_id]

    for i in range(0, len(visits)):

        if visits[i][2] == 1.0:
            mci_count = 0
            relevant_visits.clear()

        elif visits[i][2] == 2.0:
            mci_count += 1
            relevant_visits.append(visits[i])

        elif visits[i][2] == 3.0:
            break

    if  1 <= mci_count :
        mci_dict[patient_id] = relevant_visits

# %%
print('Number of patients:', len(mci_dict))

num_relevant_visits = 0

for key in mci_dict:
   num_relevant_visits += len(mci_dict[key]) 
    
print('Number of relevant visits:', num_relevant_visits)  
np.save("data/mci_dict.npy", mci_dict) 
#mci_dict['099_S_0051']
# Out:
# Number of patients: 1470
# Number of relevant visits: 5484
